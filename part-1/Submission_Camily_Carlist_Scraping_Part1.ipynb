# %% [markdown]
# # **Web Scrapping (BeautifulSoup + URLlib) Part 1**

# %% [markdown]
# **Group:** Group 1 \
# **Name:** Camily Tang Jia Lei \
# **Matrics. No:** A22EC0039
#
# **Group Members:**
#   1.  Marcus Joey Sayner (A22EC0193)
#   2. Muhammad Luqman Hakim bin Mohd Rizaudin (A22EC0086)
#   3. Camily Tang Jia Lei (A22EC0039)
#   4. Goh Jing Yang (A22EC0052)
#
# **Objective:**:
#   The objective of this project is to scrape car listings from Carlist.my, focusing on extracting key details such as car name, brand, model, price, mileage, and more. The extracted data is then saved in a CSV file for further analysis and potential use in a car market analysis.

# %% [markdown]
# # 1. Importing Libraries
# The first step in this project is to import the necessary Python libraries. These libraries are used for fetching the webpage, parsing the HTML content, and handling data.
#
# *   **urllib.request:** This module is used for sending HTTP requests and fetching the HTML content of web pages. We use it to download the webpage’s HTML content.
# *   **BeautifulSoup:** A powerful library used to parse HTML and XML documents. It provides methods to navigate and search the parse tree, making it easier to extract specific elements from the page.
# *   **csv:** A built-in Python module for reading from and writing to CSV files. It's used here to store the scraped data in a structured tabular format.
# *   **time:** The time module is used to add delays between requests, helping to avoid overwhelming the website with too many requests in a short period.
# *   **json:** This module is used for parsing JSON data. Since the car listings are embedded in a JSON-LD script, this module allows us to extract and handle that data effectively.

# %%
import urllib.request
from bs4 import BeautifulSoup, NavigableString
import csv
import time
import json

# %% [markdown]
# ## 2. Configuration
# Here, we set up the configuration for the scraping process, including the base URL for the car listings and the page range that we want to scrape. We also prepare an empty list to store the car listings and specify the output file name.
#
#
#
# *   **base_url:** The base URL is a template for the car listings pages on Carlist.my. The {} placeholder is replaced with the current page number during the scraping process. The page size is set to 25 listings per page.
# *   **start_page and end_page:** These variables define the range of pages to scrape. In this case, the scraper will fetch pages 1 and 2.
# *   **car_listings:** This list will store the data extracted from each car listing. Each listing will be appended to this list as a dictionary.
# *   **output_file:** The name of the CSV file where the scraped data will be saved.

# %%
# Configuration
base_url = "https://www.carlist.my/cars-for-sale/malaysia?page_number={}&page_size=25"
start_page = 5233    # Starting page number to scrape 
end_page = 6000      # Ending page number to scrape
car_listings = []  # List to store car listings data

output_file = 'D:/camily_carlist_listings_1.csv'

# %% [markdown]
# # 3. Helper Functions for Data Extraction
# Several helper functions are defined to extract specific details from the HTML content and embedded JSON data.

# %% [markdown]
# 3.1 Get HTML Attributes <br>
# This function retrieves the value of a specified HTML attribute from a given element. If the attribute is not found, it returns an empty string.

# %%
# Get HTML attribute or empty string if attribute doesn't exist
def get_attr(element, attr_name):
    return element.get(attr_name, '') if element else ''

# %% [markdown]
# 3.2 Extract the First Text Node <br>
# This function extracts the first visible text node inside a div element. It ignores non-text elements like tags and returns only the first piece of text content.

# %%
# Get the first text node inside a <div> (ignores non-text elements)
def get_first_text_node(div):
    for node in div.contents if div else []:
        if isinstance(node, NavigableString) and node.strip():
            return node
    return ''  # Return empty string if no text node is found

# %% [markdown]
# 3.3 Extract Mileage Data <br>
# This function searches for the meter icon in each car listing and retrieves the mileage information associated with it. If the icon is found, it returns the text next to it; otherwise, it returns an empty string.

# %%
# Extract raw mileage information from the article (after the meter icon)
def get_mileage(article):
    icon = article.find('i', class_='icon--meter')  # Find meter icon
    return str(icon.next_sibling) if icon and icon.next_sibling else ''  # Return mileage text

# %% [markdown]
# 3.4 Extract Location Data<br>
# This function retrieves the location information for each car listing. It searches for the location icon and extracts the text that follows it.

# %%
# Extract raw location information from the article (after the location icon)
def get_location(article):
    icon = article.find('i', class_='icon--location')  # Find location icon
    if not icon:
        return ''
    text = ''
    for sib in icon.next_siblings:  # Loop through siblings after icon
        if isinstance(sib, NavigableString):
            text += str(sib)
        elif getattr(sib, 'name', None) == 'span':
            text += sib.get_text()
        else:
            break
    return text  # Return extracted location text

# %% [markdown]
# 3.5 Extract JSON-LD Data <br>
# This function extracts the embedded JSON-LD data from the webpage. JSON-LD is used to represent structured data about the car listings. The function looks for the script tag containing this data, parses it, and returns the list of car listings.

# %%
# Pull JSON-LD block containing the car listings from the page
def extract_json_ld(soup):
    for script in soup.find_all('script', type='application/ld+json'):
        try:
            data = json.loads(script.string)  # Parse the JSON-LD data
            if isinstance(data, list):
                for d in data:
                    if 'itemListElement' in d:
                        return d['itemListElement']  # Return list of car listings
        except:
            continue
    return None  # Return None if no valid JSON-LD is found

# %% [markdown]
# # 4. Tracking Execution Time
# This line captures the current time (in seconds) before the main scraping loop begins. The time.time() function returns the time as a floating-point number. By capturing the start time, we can later calculate the total execution time of the script. This helps in assessing the efficiency of the scraping process, particularly useful when scraping multiple pages or large amounts of data. It allows for performance optimization and comparison with future improvements or different approaches.

# %%
# Start time
start_time = time.time()

# %% [markdown]
# # 5. Main Scraping Loop
# In this section, the main scraping process is performed. We iterate over the specified pages and extract the relevant car listing data.

# %%
# Main scraping loop
for page_num in range(start_page, end_page + 1):
    url = base_url.format(page_num)  # Generate URL for the current page
    print(f"\n🔎 Extracting page {page_num} - {url}")

    # Load the page and parse it with BeautifulSoup
    req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
    html = urllib.request.urlopen(req).read()
    soup = BeautifulSoup(html, 'html.parser')

    # Find all articles (car listings) and extract JSON-LD data
    articles = soup.find_all('article', class_='listing')
    ld_json = extract_json_ld(soup)
    if not ld_json:
        print("⚠️ No JSON-LD found on this page.")
        continue

    page_count = 0
    # Loop through articles and corresponding JSON-LD data
    for article, item in zip(articles, ld_json):
        car = item['item']  # Extract JSON details for the car

        # Extract fields from the <article> element’s attributes (HTML-based fields)
        name = get_attr(article, 'data-title')
        brand = get_attr(article, 'data-make')
        model = get_attr(article, 'data-model')
        body = get_attr(article, 'data-body-type')
        transmission = get_attr(article, 'data-transmission')
        installment = get_attr(article, 'data-installment')

        # Extract exactly what is displayed on the page (visible text-based fields)
        mileage = get_mileage(article)
        sales_channel = get_first_text_node(article.find('div', class_='listing__spec--dealer'))
        location = get_location(article)

        # Extract additional fields from the JSON-LD data
        year = car.get('vehicleModelDate', '')
        fuel = car.get('fuelType', '')
        color = car.get('color', '')
        price = car.get('offers', {}).get('price', '')
        condition = car.get('itemCondition', '')
        seats = car.get('seatingCapacity', '')

        # Append the extracted data to the car_listings list
        car_listings.append({
            'Car Name': name,
            'Car Brand': brand,
            'Car Model': model,
            'Manufacture Year': year,
            'Body Type': body,
            'Fuel Type': fuel,
            'Mileage': mileage,
            'Transmission': transmission,
            'Color': color,
            'Price': price,
            'Installment': installment,
            'Condition': condition,
            'Seating Capacity': seats,
            'Location': location,
            'Sales Channel': sales_channel
        })
        page_count += 1

    print(f"✅ Found {page_count} cars on page {page_num}")
    print(f"📄 Total scraped: {len(car_listings)}")
    time.sleep(2)  # Sleep to avoid making too many requests in a short time
# Out:
# 🔎 Extracting page 5233 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5233&page_size=25
# ✅ Found 25 cars on page 5233
# 📄 Total scraped: 25
#
# 🔎 Extracting page 5234 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5234&page_size=25
# ✅ Found 25 cars on page 5234
# 📄 Total scraped: 50
#
# 🔎 Extracting page 5235 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5235&page_size=25
# ✅ Found 25 cars on page 5235
# 📄 Total scraped: 75
#
# 🔎 Extracting page 5236 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5236&page_size=25
# ✅ Found 25 cars on page 5236
# 📄 Total scraped: 100
#
# 🔎 Extracting page 5237 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5237&page_size=25
# ✅ Found 25 cars on page 5237
# 📄 Total scraped: 125
#
# 🔎 Extracting page 5238 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5238&page_size=25
# ✅ Found 25 cars on page 5238
# 📄 Total scraped: 150
#
# 🔎 Extracting page 5239 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5239&page_size=25
# ✅ Found 25 cars on page 5239
# 📄 Total scraped: 175
#
# 🔎 Extracting page 5240 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5240&page_size=25
# ✅ Found 25 cars on page 5240
# 📄 Total scraped: 200
#
# 🔎 Extracting page 5241 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5241&page_size=25
# ✅ Found 25 cars on page 5241
# 📄 Total scraped: 225
#
# 🔎 Extracting page 5242 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5242&page_size=25
# ✅ Found 25 cars on page 5242
# 📄 Total scraped: 250
#
# 🔎 Extracting page 5243 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5243&page_size=25
# ✅ Found 25 cars on page 5243
# 📄 Total scraped: 275
#
# 🔎 Extracting page 5244 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5244&page_size=25
# ✅ Found 25 cars on page 5244
# 📄 Total scraped: 300
#
# 🔎 Extracting page 5245 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5245&page_size=25
# ✅ Found 25 cars on page 5245
# 📄 Total scraped: 325
#
# 🔎 Extracting page 5246 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5246&page_size=25
# ✅ Found 25 cars on page 5246
# 📄 Total scraped: 350
#
# 🔎 Extracting page 5247 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5247&page_size=25
# ✅ Found 25 cars on page 5247
# 📄 Total scraped: 375
#
# 🔎 Extracting page 5248 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5248&page_size=25
# ✅ Found 25 cars on page 5248
# 📄 Total scraped: 400
#
# 🔎 Extracting page 5249 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5249&page_size=25
# ✅ Found 25 cars on page 5249
# 📄 Total scraped: 425
#
# 🔎 Extracting page 5250 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5250&page_size=25
# ✅ Found 25 cars on page 5250
# 📄 Total scraped: 450
#
# 🔎 Extracting page 5251 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5251&page_size=25
# ✅ Found 25 cars on page 5251
# 📄 Total scraped: 475
#
# 🔎 Extracting page 5252 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5252&page_size=25
# ✅ Found 25 cars on page 5252
# 📄 Total scraped: 500
#
# 🔎 Extracting page 5253 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5253&page_size=25
# ✅ Found 25 cars on page 5253
# 📄 Total scraped: 525
#
# 🔎 Extracting page 5254 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5254&page_size=25
# ✅ Found 25 cars on page 5254
# 📄 Total scraped: 550
#
# 🔎 Extracting page 5255 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5255&page_size=25
# ✅ Found 25 cars on page 5255
# 📄 Total scraped: 575
#
# 🔎 Extracting page 5256 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5256&page_size=25
# ✅ Found 25 cars on page 5256
# 📄 Total scraped: 600
#
# 🔎 Extracting page 5257 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5257&page_size=25
# ✅ Found 25 cars on page 5257
# 📄 Total scraped: 625
#
# 🔎 Extracting page 5258 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5258&page_size=25
# ✅ Found 25 cars on page 5258
# 📄 Total scraped: 650
#
# 🔎 Extracting page 5259 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5259&page_size=25
# ✅ Found 25 cars on page 5259
# 📄 Total scraped: 675
#
# 🔎 Extracting page 5260 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5260&page_size=25
# ✅ Found 25 cars on page 5260
# 📄 Total scraped: 700
#
# 🔎 Extracting page 5261 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5261&page_size=25
# ✅ Found 25 cars on page 5261
# 📄 Total scraped: 725
#
# 🔎 Extracting page 5262 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5262&page_size=25
# ✅ Found 25 cars on page 5262
# 📄 Total scraped: 750
#
# 🔎 Extracting page 5263 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5263&page_size=25
# ✅ Found 25 cars on page 5263
# 📄 Total scraped: 775
#
# 🔎 Extracting page 5264 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5264&page_size=25
# ✅ Found 25 cars on page 5264
# 📄 Total scraped: 800
#
# 🔎 Extracting page 5265 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5265&page_size=25
# ✅ Found 25 cars on page 5265
# 📄 Total scraped: 825
#
# 🔎 Extracting page 5266 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5266&page_size=25
# ✅ Found 25 cars on page 5266
# 📄 Total scraped: 850
#
# 🔎 Extracting page 5267 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5267&page_size=25
# ✅ Found 25 cars on page 5267
# 📄 Total scraped: 875
#
# 🔎 Extracting page 5268 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5268&page_size=25
# ✅ Found 25 cars on page 5268
# 📄 Total scraped: 900
#
# 🔎 Extracting page 5269 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5269&page_size=25
# ✅ Found 25 cars on page 5269
# 📄 Total scraped: 925
#
# 🔎 Extracting page 5270 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5270&page_size=25
# ✅ Found 25 cars on page 5270
# 📄 Total scraped: 950
#
# 🔎 Extracting page 5271 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5271&page_size=25
# ✅ Found 25 cars on page 5271
# 📄 Total scraped: 975
#
# 🔎 Extracting page 5272 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5272&page_size=25
# ✅ Found 25 cars on page 5272
# 📄 Total scraped: 1000
#
# 🔎 Extracting page 5273 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5273&page_size=25
# ✅ Found 25 cars on page 5273
# 📄 Total scraped: 1025
#
# 🔎 Extracting page 5274 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5274&page_size=25
# ✅ Found 25 cars on page 5274
# 📄 Total scraped: 1050
#
# 🔎 Extracting page 5275 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5275&page_size=25
# ✅ Found 25 cars on page 5275
# 📄 Total scraped: 1075
#
# 🔎 Extracting page 5276 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5276&page_size=25
# ✅ Found 25 cars on page 5276
# 📄 Total scraped: 1100
#
# 🔎 Extracting page 5277 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5277&page_size=25
# ✅ Found 25 cars on page 5277
# 📄 Total scraped: 1125
#
# 🔎 Extracting page 5278 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5278&page_size=25
# ✅ Found 25 cars on page 5278
# 📄 Total scraped: 1150
#
# 🔎 Extracting page 5279 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5279&page_size=25
# ✅ Found 25 cars on page 5279
# 📄 Total scraped: 1175
#
# 🔎 Extracting page 5280 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5280&page_size=25
# ✅ Found 25 cars on page 5280
# 📄 Total scraped: 1200
#
# 🔎 Extracting page 5281 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5281&page_size=25
# ✅ Found 25 cars on page 5281
# 📄 Total scraped: 1225
#
# 🔎 Extracting page 5282 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5282&page_size=25
# ✅ Found 25 cars on page 5282
# 📄 Total scraped: 1250
#
# 🔎 Extracting page 5283 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5283&page_size=25
# ✅ Found 25 cars on page 5283
# 📄 Total scraped: 1275
#
# 🔎 Extracting page 5284 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5284&page_size=25
# ✅ Found 25 cars on page 5284
# 📄 Total scraped: 1300
#
# 🔎 Extracting page 5285 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5285&page_size=25
# ✅ Found 25 cars on page 5285
# 📄 Total scraped: 1325
#
# 🔎 Extracting page 5286 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5286&page_size=25
# ✅ Found 25 cars on page 5286
# 📄 Total scraped: 1350
#
# 🔎 Extracting page 5287 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5287&page_size=25
# ✅ Found 25 cars on page 5287
# 📄 Total scraped: 1375
#
# 🔎 Extracting page 5288 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5288&page_size=25
# ✅ Found 25 cars on page 5288
# 📄 Total scraped: 1400
#
# 🔎 Extracting page 5289 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5289&page_size=25
# ✅ Found 25 cars on page 5289
# 📄 Total scraped: 1425
#
# 🔎 Extracting page 5290 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5290&page_size=25
# ✅ Found 25 cars on page 5290
# 📄 Total scraped: 1450
#
# 🔎 Extracting page 5291 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5291&page_size=25
# ✅ Found 25 cars on page 5291
# 📄 Total scraped: 1475
#
# 🔎 Extracting page 5292 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5292&page_size=25
# ✅ Found 25 cars on page 5292
# 📄 Total scraped: 1500
#
# 🔎 Extracting page 5293 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5293&page_size=25
# ✅ Found 25 cars on page 5293
# 📄 Total scraped: 1525
#
# 🔎 Extracting page 5294 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5294&page_size=25
# ✅ Found 25 cars on page 5294
# 📄 Total scraped: 1550
#
# 🔎 Extracting page 5295 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5295&page_size=25
# ✅ Found 25 cars on page 5295
# 📄 Total scraped: 1575
#
# 🔎 Extracting page 5296 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5296&page_size=25
# ✅ Found 25 cars on page 5296
# 📄 Total scraped: 1600
#
# 🔎 Extracting page 5297 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5297&page_size=25
# ✅ Found 25 cars on page 5297
# 📄 Total scraped: 1625
#
# 🔎 Extracting page 5298 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5298&page_size=25
# ✅ Found 25 cars on page 5298
# 📄 Total scraped: 1650
#
# 🔎 Extracting page 5299 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5299&page_size=25
# ✅ Found 25 cars on page 5299
# 📄 Total scraped: 1675
#
# 🔎 Extracting page 5300 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5300&page_size=25
# ✅ Found 25 cars on page 5300
# 📄 Total scraped: 1700
#
# 🔎 Extracting page 5301 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5301&page_size=25
# ✅ Found 25 cars on page 5301
# 📄 Total scraped: 1725
#
# 🔎 Extracting page 5302 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5302&page_size=25
# ✅ Found 25 cars on page 5302
# 📄 Total scraped: 1750
#
# 🔎 Extracting page 5303 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5303&page_size=25
# ✅ Found 25 cars on page 5303
# 📄 Total scraped: 1775
#
# 🔎 Extracting page 5304 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5304&page_size=25
# ✅ Found 25 cars on page 5304
# 📄 Total scraped: 1800
#
# 🔎 Extracting page 5305 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5305&page_size=25
# ✅ Found 25 cars on page 5305
# 📄 Total scraped: 1825
#
# 🔎 Extracting page 5306 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5306&page_size=25
# ✅ Found 25 cars on page 5306
# 📄 Total scraped: 1850
#
# 🔎 Extracting page 5307 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5307&page_size=25
# ✅ Found 25 cars on page 5307
# 📄 Total scraped: 1875
#
# 🔎 Extracting page 5308 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5308&page_size=25
# ✅ Found 25 cars on page 5308
# 📄 Total scraped: 1900
#
# 🔎 Extracting page 5309 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5309&page_size=25
# ✅ Found 25 cars on page 5309
# 📄 Total scraped: 1925
#
# 🔎 Extracting page 5310 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5310&page_size=25
# ✅ Found 25 cars on page 5310
# 📄 Total scraped: 1950
#
# 🔎 Extracting page 5311 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5311&page_size=25
# ✅ Found 25 cars on page 5311
# 📄 Total scraped: 1975
#
# 🔎 Extracting page 5312 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5312&page_size=25
# ✅ Found 25 cars on page 5312
# 📄 Total scraped: 2000
#
# 🔎 Extracting page 5313 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5313&page_size=25
# ✅ Found 25 cars on page 5313
# 📄 Total scraped: 2025
#
# 🔎 Extracting page 5314 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5314&page_size=25
# ✅ Found 25 cars on page 5314
# 📄 Total scraped: 2050
#
# 🔎 Extracting page 5315 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5315&page_size=25
# ✅ Found 25 cars on page 5315
# 📄 Total scraped: 2075
#
# 🔎 Extracting page 5316 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5316&page_size=25
# ✅ Found 25 cars on page 5316
# 📄 Total scraped: 2100
#
# 🔎 Extracting page 5317 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5317&page_size=25
# ✅ Found 25 cars on page 5317
# 📄 Total scraped: 2125
#
# 🔎 Extracting page 5318 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5318&page_size=25
# ✅ Found 25 cars on page 5318
# 📄 Total scraped: 2150
#
# 🔎 Extracting page 5319 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5319&page_size=25
# ✅ Found 25 cars on page 5319
# 📄 Total scraped: 2175
#
# 🔎 Extracting page 5320 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5320&page_size=25
# ✅ Found 25 cars on page 5320
# 📄 Total scraped: 2200
#
# 🔎 Extracting page 5321 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5321&page_size=25
# ✅ Found 25 cars on page 5321
# 📄 Total scraped: 2225
#
# 🔎 Extracting page 5322 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5322&page_size=25
# ✅ Found 25 cars on page 5322
# 📄 Total scraped: 2250
#
# 🔎 Extracting page 5323 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5323&page_size=25
# ✅ Found 25 cars on page 5323
# 📄 Total scraped: 2275
#
# 🔎 Extracting page 5324 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5324&page_size=25
# ✅ Found 25 cars on page 5324
# 📄 Total scraped: 2300
#
# 🔎 Extracting page 5325 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5325&page_size=25
# ✅ Found 25 cars on page 5325
# 📄 Total scraped: 2325
#
# 🔎 Extracting page 5326 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5326&page_size=25
# ✅ Found 25 cars on page 5326
# 📄 Total scraped: 2350
#
# 🔎 Extracting page 5327 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5327&page_size=25
# ✅ Found 25 cars on page 5327
# 📄 Total scraped: 2375
#
# 🔎 Extracting page 5328 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5328&page_size=25
# ✅ Found 25 cars on page 5328
# 📄 Total scraped: 2400
#
# 🔎 Extracting page 5329 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5329&page_size=25
# ✅ Found 25 cars on page 5329
# 📄 Total scraped: 2425
#
# 🔎 Extracting page 5330 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5330&page_size=25
# ✅ Found 25 cars on page 5330
# 📄 Total scraped: 2450
#
# 🔎 Extracting page 5331 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5331&page_size=25
# ✅ Found 25 cars on page 5331
# 📄 Total scraped: 2475
#
# 🔎 Extracting page 5332 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5332&page_size=25
# ✅ Found 25 cars on page 5332
# 📄 Total scraped: 2500
#
# 🔎 Extracting page 5333 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5333&page_size=25
# ✅ Found 25 cars on page 5333
# 📄 Total scraped: 2525
#
# 🔎 Extracting page 5334 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5334&page_size=25
# ✅ Found 25 cars on page 5334
# 📄 Total scraped: 2550
#
# 🔎 Extracting page 5335 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5335&page_size=25
# ✅ Found 25 cars on page 5335
# 📄 Total scraped: 2575
#
# 🔎 Extracting page 5336 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5336&page_size=25
# ✅ Found 25 cars on page 5336
# 📄 Total scraped: 2600
#
# 🔎 Extracting page 5337 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5337&page_size=25
# ✅ Found 25 cars on page 5337
# 📄 Total scraped: 2625
#
# 🔎 Extracting page 5338 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5338&page_size=25
# ✅ Found 25 cars on page 5338
# 📄 Total scraped: 2650
#
# 🔎 Extracting page 5339 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5339&page_size=25
# ✅ Found 25 cars on page 5339
# 📄 Total scraped: 2675
#
# 🔎 Extracting page 5340 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5340&page_size=25
# ✅ Found 25 cars on page 5340
# 📄 Total scraped: 2700
#
# 🔎 Extracting page 5341 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5341&page_size=25
# ✅ Found 25 cars on page 5341
# 📄 Total scraped: 2725
#
# 🔎 Extracting page 5342 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5342&page_size=25
# ✅ Found 25 cars on page 5342
# 📄 Total scraped: 2750
#
# 🔎 Extracting page 5343 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5343&page_size=25
# ✅ Found 25 cars on page 5343
# 📄 Total scraped: 2775
#
# 🔎 Extracting page 5344 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5344&page_size=25
# ✅ Found 25 cars on page 5344
# 📄 Total scraped: 2800
#
# 🔎 Extracting page 5345 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5345&page_size=25
# ✅ Found 25 cars on page 5345
# 📄 Total scraped: 2825
#
# 🔎 Extracting page 5346 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5346&page_size=25
# ✅ Found 25 cars on page 5346
# 📄 Total scraped: 2850
#
# 🔎 Extracting page 5347 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5347&page_size=25
# ✅ Found 25 cars on page 5347
# 📄 Total scraped: 2875
#
# 🔎 Extracting page 5348 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5348&page_size=25
# ✅ Found 25 cars on page 5348
# 📄 Total scraped: 2900
#
# 🔎 Extracting page 5349 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5349&page_size=25
# ✅ Found 25 cars on page 5349
# 📄 Total scraped: 2925
#
# 🔎 Extracting page 5350 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5350&page_size=25
# ✅ Found 25 cars on page 5350
# 📄 Total scraped: 2950
#
# 🔎 Extracting page 5351 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5351&page_size=25
# ✅ Found 25 cars on page 5351
# 📄 Total scraped: 2975
#
# 🔎 Extracting page 5352 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5352&page_size=25
# ✅ Found 25 cars on page 5352
# 📄 Total scraped: 3000
#
# 🔎 Extracting page 5353 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5353&page_size=25
# ✅ Found 25 cars on page 5353
# 📄 Total scraped: 3025
#
# 🔎 Extracting page 5354 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5354&page_size=25
# ✅ Found 25 cars on page 5354
# 📄 Total scraped: 3050
#
# 🔎 Extracting page 5355 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5355&page_size=25
# ✅ Found 25 cars on page 5355
# 📄 Total scraped: 3075
#
# 🔎 Extracting page 5356 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5356&page_size=25
# ✅ Found 25 cars on page 5356
# 📄 Total scraped: 3100
#
# 🔎 Extracting page 5357 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5357&page_size=25
# ✅ Found 25 cars on page 5357
# 📄 Total scraped: 3125
#
# 🔎 Extracting page 5358 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5358&page_size=25
# ✅ Found 25 cars on page 5358
# 📄 Total scraped: 3150
#
# 🔎 Extracting page 5359 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5359&page_size=25
# ✅ Found 25 cars on page 5359
# 📄 Total scraped: 3175
#
# 🔎 Extracting page 5360 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5360&page_size=25
# ✅ Found 25 cars on page 5360
# 📄 Total scraped: 3200
#
# 🔎 Extracting page 5361 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5361&page_size=25
# ✅ Found 25 cars on page 5361
# 📄 Total scraped: 3225
#
# 🔎 Extracting page 5362 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5362&page_size=25
# ✅ Found 25 cars on page 5362
# 📄 Total scraped: 3250
#
# 🔎 Extracting page 5363 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5363&page_size=25
# ✅ Found 25 cars on page 5363
# 📄 Total scraped: 3275
#
# 🔎 Extracting page 5364 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5364&page_size=25
# ✅ Found 25 cars on page 5364
# 📄 Total scraped: 3300
#
# 🔎 Extracting page 5365 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5365&page_size=25
# ✅ Found 25 cars on page 5365
# 📄 Total scraped: 3325
#
# 🔎 Extracting page 5366 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5366&page_size=25
# ✅ Found 25 cars on page 5366
# 📄 Total scraped: 3350
#
# 🔎 Extracting page 5367 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5367&page_size=25
# ✅ Found 25 cars on page 5367
# 📄 Total scraped: 3375
#
# 🔎 Extracting page 5368 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5368&page_size=25
# ✅ Found 25 cars on page 5368
# 📄 Total scraped: 3400
#
# 🔎 Extracting page 5369 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5369&page_size=25
# ✅ Found 25 cars on page 5369
# 📄 Total scraped: 3425
#
# 🔎 Extracting page 5370 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5370&page_size=25
# ✅ Found 25 cars on page 5370
# 📄 Total scraped: 3450
#
# 🔎 Extracting page 5371 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5371&page_size=25
# ✅ Found 25 cars on page 5371
# 📄 Total scraped: 3475
#
# 🔎 Extracting page 5372 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5372&page_size=25
# ✅ Found 25 cars on page 5372
# 📄 Total scraped: 3500
#
# 🔎 Extracting page 5373 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5373&page_size=25
# ✅ Found 25 cars on page 5373
# 📄 Total scraped: 3525
#
# 🔎 Extracting page 5374 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5374&page_size=25
# ✅ Found 25 cars on page 5374
# 📄 Total scraped: 3550
#
# 🔎 Extracting page 5375 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5375&page_size=25
# ✅ Found 25 cars on page 5375
# 📄 Total scraped: 3575
#
# 🔎 Extracting page 5376 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5376&page_size=25
# ✅ Found 25 cars on page 5376
# 📄 Total scraped: 3600
#
# 🔎 Extracting page 5377 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5377&page_size=25
# ✅ Found 25 cars on page 5377
# 📄 Total scraped: 3625
#
# 🔎 Extracting page 5378 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5378&page_size=25
# ✅ Found 25 cars on page 5378
# 📄 Total scraped: 3650
#
# 🔎 Extracting page 5379 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5379&page_size=25
# ✅ Found 25 cars on page 5379
# 📄 Total scraped: 3675
#
# 🔎 Extracting page 5380 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5380&page_size=25
# ✅ Found 25 cars on page 5380
# 📄 Total scraped: 3700
#
# 🔎 Extracting page 5381 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5381&page_size=25
# ✅ Found 25 cars on page 5381
# 📄 Total scraped: 3725
#
# 🔎 Extracting page 5382 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5382&page_size=25
# ✅ Found 25 cars on page 5382
# 📄 Total scraped: 3750
#
# 🔎 Extracting page 5383 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5383&page_size=25
# ✅ Found 25 cars on page 5383
# 📄 Total scraped: 3775
#
# 🔎 Extracting page 5384 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5384&page_size=25
# ✅ Found 25 cars on page 5384
# 📄 Total scraped: 3800
#
# 🔎 Extracting page 5385 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5385&page_size=25
# ✅ Found 25 cars on page 5385
# 📄 Total scraped: 3825
#
# 🔎 Extracting page 5386 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5386&page_size=25
# ✅ Found 25 cars on page 5386
# 📄 Total scraped: 3850
#
# 🔎 Extracting page 5387 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5387&page_size=25
# ✅ Found 25 cars on page 5387
# 📄 Total scraped: 3875
#
# 🔎 Extracting page 5388 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5388&page_size=25
# ✅ Found 25 cars on page 5388
# 📄 Total scraped: 3900
#
# 🔎 Extracting page 5389 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5389&page_size=25
# ✅ Found 25 cars on page 5389
# 📄 Total scraped: 3925
#
# 🔎 Extracting page 5390 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5390&page_size=25
# ✅ Found 25 cars on page 5390
# 📄 Total scraped: 3950
#
# 🔎 Extracting page 5391 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5391&page_size=25
# ✅ Found 25 cars on page 5391
# 📄 Total scraped: 3975
#
# 🔎 Extracting page 5392 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5392&page_size=25
# ✅ Found 25 cars on page 5392
# 📄 Total scraped: 4000
#
# 🔎 Extracting page 5393 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5393&page_size=25
# ✅ Found 25 cars on page 5393
# 📄 Total scraped: 4025
#
# 🔎 Extracting page 5394 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5394&page_size=25
# ✅ Found 25 cars on page 5394
# 📄 Total scraped: 4050
#
# 🔎 Extracting page 5395 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5395&page_size=25
# ✅ Found 25 cars on page 5395
# 📄 Total scraped: 4075
#
# 🔎 Extracting page 5396 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5396&page_size=25
# ✅ Found 25 cars on page 5396
# 📄 Total scraped: 4100
#
# 🔎 Extracting page 5397 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5397&page_size=25
# ✅ Found 25 cars on page 5397
# 📄 Total scraped: 4125
#
# 🔎 Extracting page 5398 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5398&page_size=25
# ✅ Found 25 cars on page 5398
# 📄 Total scraped: 4150
#
# 🔎 Extracting page 5399 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5399&page_size=25
# ✅ Found 25 cars on page 5399
# 📄 Total scraped: 4175
#
# 🔎 Extracting page 5400 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5400&page_size=25
# ✅ Found 25 cars on page 5400
# 📄 Total scraped: 4200
#
# 🔎 Extracting page 5401 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5401&page_size=25
# ✅ Found 25 cars on page 5401
# 📄 Total scraped: 4225
#
# 🔎 Extracting page 5402 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5402&page_size=25
# ✅ Found 25 cars on page 5402
# 📄 Total scraped: 4250
#
# 🔎 Extracting page 5403 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5403&page_size=25
# ✅ Found 25 cars on page 5403
# 📄 Total scraped: 4275
#
# 🔎 Extracting page 5404 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5404&page_size=25
# ✅ Found 25 cars on page 5404
# 📄 Total scraped: 4300
#
# 🔎 Extracting page 5405 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5405&page_size=25
# ✅ Found 25 cars on page 5405
# 📄 Total scraped: 4325
#
# 🔎 Extracting page 5406 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5406&page_size=25
# ✅ Found 25 cars on page 5406
# 📄 Total scraped: 4350
#
# 🔎 Extracting page 5407 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5407&page_size=25
# ✅ Found 25 cars on page 5407
# 📄 Total scraped: 4375
#
# 🔎 Extracting page 5408 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5408&page_size=25
# ✅ Found 25 cars on page 5408
# 📄 Total scraped: 4400
#
# 🔎 Extracting page 5409 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5409&page_size=25
# ✅ Found 25 cars on page 5409
# 📄 Total scraped: 4425
#
# 🔎 Extracting page 5410 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5410&page_size=25
# ✅ Found 25 cars on page 5410
# 📄 Total scraped: 4450
#
# 🔎 Extracting page 5411 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5411&page_size=25
# ✅ Found 25 cars on page 5411
# 📄 Total scraped: 4475
#
# 🔎 Extracting page 5412 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5412&page_size=25
# ✅ Found 25 cars on page 5412
# 📄 Total scraped: 4500
#
# 🔎 Extracting page 5413 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5413&page_size=25
# ✅ Found 25 cars on page 5413
# 📄 Total scraped: 4525
#
# 🔎 Extracting page 5414 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5414&page_size=25
# ✅ Found 25 cars on page 5414
# 📄 Total scraped: 4550
#
# 🔎 Extracting page 5415 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5415&page_size=25
# ✅ Found 25 cars on page 5415
# 📄 Total scraped: 4575
#
# 🔎 Extracting page 5416 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5416&page_size=25
# ✅ Found 25 cars on page 5416
# 📄 Total scraped: 4600
#
# 🔎 Extracting page 5417 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5417&page_size=25
# ✅ Found 25 cars on page 5417
# 📄 Total scraped: 4625
#
# 🔎 Extracting page 5418 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5418&page_size=25
# ✅ Found 25 cars on page 5418
# 📄 Total scraped: 4650
#
# 🔎 Extracting page 5419 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5419&page_size=25
# ✅ Found 25 cars on page 5419
# 📄 Total scraped: 4675
#
# 🔎 Extracting page 5420 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5420&page_size=25
# ✅ Found 25 cars on page 5420
# 📄 Total scraped: 4700
#
# 🔎 Extracting page 5421 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5421&page_size=25
# ✅ Found 25 cars on page 5421
# 📄 Total scraped: 4725
#
# 🔎 Extracting page 5422 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5422&page_size=25
# ✅ Found 25 cars on page 5422
# 📄 Total scraped: 4750
#
# 🔎 Extracting page 5423 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5423&page_size=25
# ✅ Found 25 cars on page 5423
# 📄 Total scraped: 4775
#
# 🔎 Extracting page 5424 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5424&page_size=25
# ✅ Found 25 cars on page 5424
# 📄 Total scraped: 4800
#
# 🔎 Extracting page 5425 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5425&page_size=25
# ✅ Found 25 cars on page 5425
# 📄 Total scraped: 4825
#
# 🔎 Extracting page 5426 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5426&page_size=25
# ✅ Found 25 cars on page 5426
# 📄 Total scraped: 4850
#
# 🔎 Extracting page 5427 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5427&page_size=25
# ✅ Found 25 cars on page 5427
# 📄 Total scraped: 4875
#
# 🔎 Extracting page 5428 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5428&page_size=25
# ✅ Found 25 cars on page 5428
# 📄 Total scraped: 4900
#
# 🔎 Extracting page 5429 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5429&page_size=25
# ✅ Found 25 cars on page 5429
# 📄 Total scraped: 4925
#
# 🔎 Extracting page 5430 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5430&page_size=25
# ✅ Found 25 cars on page 5430
# 📄 Total scraped: 4950
#
# 🔎 Extracting page 5431 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5431&page_size=25
# ✅ Found 25 cars on page 5431
# 📄 Total scraped: 4975
#
# 🔎 Extracting page 5432 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5432&page_size=25
# ✅ Found 25 cars on page 5432
# 📄 Total scraped: 5000
#
# 🔎 Extracting page 5433 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5433&page_size=25
# ✅ Found 25 cars on page 5433
# 📄 Total scraped: 5025
#
# 🔎 Extracting page 5434 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5434&page_size=25
# ✅ Found 25 cars on page 5434
# 📄 Total scraped: 5050
#
# 🔎 Extracting page 5435 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5435&page_size=25
# ✅ Found 25 cars on page 5435
# 📄 Total scraped: 5075
#
# 🔎 Extracting page 5436 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5436&page_size=25
# ✅ Found 25 cars on page 5436
# 📄 Total scraped: 5100
#
# 🔎 Extracting page 5437 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5437&page_size=25
# ✅ Found 25 cars on page 5437
# 📄 Total scraped: 5125
#
# 🔎 Extracting page 5438 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5438&page_size=25
# ✅ Found 25 cars on page 5438
# 📄 Total scraped: 5150
#
# 🔎 Extracting page 5439 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5439&page_size=25
# ✅ Found 25 cars on page 5439
# 📄 Total scraped: 5175
#
# 🔎 Extracting page 5440 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5440&page_size=25
# ✅ Found 25 cars on page 5440
# 📄 Total scraped: 5200
#
# 🔎 Extracting page 5441 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5441&page_size=25
# ✅ Found 25 cars on page 5441
# 📄 Total scraped: 5225
#
# 🔎 Extracting page 5442 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5442&page_size=25
# ✅ Found 25 cars on page 5442
# 📄 Total scraped: 5250
#
# 🔎 Extracting page 5443 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5443&page_size=25
# ✅ Found 25 cars on page 5443
# 📄 Total scraped: 5275
#
# 🔎 Extracting page 5444 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5444&page_size=25
# ✅ Found 25 cars on page 5444
# 📄 Total scraped: 5300
#
# 🔎 Extracting page 5445 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5445&page_size=25
# ✅ Found 25 cars on page 5445
# 📄 Total scraped: 5325
#
# 🔎 Extracting page 5446 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5446&page_size=25
# ✅ Found 25 cars on page 5446
# 📄 Total scraped: 5350
#
# 🔎 Extracting page 5447 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5447&page_size=25
# ✅ Found 25 cars on page 5447
# 📄 Total scraped: 5375
#
# 🔎 Extracting page 5448 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5448&page_size=25
# ✅ Found 25 cars on page 5448
# 📄 Total scraped: 5400
#
# 🔎 Extracting page 5449 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5449&page_size=25
# ✅ Found 25 cars on page 5449
# 📄 Total scraped: 5425
#
# 🔎 Extracting page 5450 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5450&page_size=25
# ✅ Found 25 cars on page 5450
# 📄 Total scraped: 5450
#
# 🔎 Extracting page 5451 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5451&page_size=25
# ✅ Found 25 cars on page 5451
# 📄 Total scraped: 5475
#
# 🔎 Extracting page 5452 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5452&page_size=25
# ✅ Found 25 cars on page 5452
# 📄 Total scraped: 5500
#
# 🔎 Extracting page 5453 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5453&page_size=25
# ✅ Found 25 cars on page 5453
# 📄 Total scraped: 5525
#
# 🔎 Extracting page 5454 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5454&page_size=25
# ✅ Found 25 cars on page 5454
# 📄 Total scraped: 5550
#
# 🔎 Extracting page 5455 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5455&page_size=25
# ✅ Found 25 cars on page 5455
# 📄 Total scraped: 5575
#
# 🔎 Extracting page 5456 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5456&page_size=25
# ✅ Found 25 cars on page 5456
# 📄 Total scraped: 5600
#
# 🔎 Extracting page 5457 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5457&page_size=25
# ✅ Found 25 cars on page 5457
# 📄 Total scraped: 5625
#
# 🔎 Extracting page 5458 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5458&page_size=25
# ✅ Found 25 cars on page 5458
# 📄 Total scraped: 5650
#
# 🔎 Extracting page 5459 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5459&page_size=25
# ✅ Found 25 cars on page 5459
# 📄 Total scraped: 5675
#
# 🔎 Extracting page 5460 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5460&page_size=25
# ✅ Found 25 cars on page 5460
# 📄 Total scraped: 5700
#
# 🔎 Extracting page 5461 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5461&page_size=25
# ✅ Found 25 cars on page 5461
# 📄 Total scraped: 5725
#
# 🔎 Extracting page 5462 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5462&page_size=25
# ✅ Found 25 cars on page 5462
# 📄 Total scraped: 5750
#
# 🔎 Extracting page 5463 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5463&page_size=25
# ✅ Found 25 cars on page 5463
# 📄 Total scraped: 5775
#
# 🔎 Extracting page 5464 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5464&page_size=25
# ✅ Found 25 cars on page 5464
# 📄 Total scraped: 5800
#
# 🔎 Extracting page 5465 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5465&page_size=25
# ✅ Found 25 cars on page 5465
# 📄 Total scraped: 5825
#
# 🔎 Extracting page 5466 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5466&page_size=25
# ✅ Found 25 cars on page 5466
# 📄 Total scraped: 5850
#
# 🔎 Extracting page 5467 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5467&page_size=25
# ✅ Found 25 cars on page 5467
# 📄 Total scraped: 5875
#
# 🔎 Extracting page 5468 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5468&page_size=25
# ✅ Found 25 cars on page 5468
# 📄 Total scraped: 5900
#
# 🔎 Extracting page 5469 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5469&page_size=25
# ✅ Found 25 cars on page 5469
# 📄 Total scraped: 5925
#
# 🔎 Extracting page 5470 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5470&page_size=25
# ✅ Found 25 cars on page 5470
# 📄 Total scraped: 5950
#
# 🔎 Extracting page 5471 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5471&page_size=25
# ✅ Found 25 cars on page 5471
# 📄 Total scraped: 5975
#
# 🔎 Extracting page 5472 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5472&page_size=25
# ✅ Found 25 cars on page 5472
# 📄 Total scraped: 6000
#
# 🔎 Extracting page 5473 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5473&page_size=25
# ✅ Found 25 cars on page 5473
# 📄 Total scraped: 6025
#
# 🔎 Extracting page 5474 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5474&page_size=25
# ✅ Found 25 cars on page 5474
# 📄 Total scraped: 6050
#
# 🔎 Extracting page 5475 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5475&page_size=25
# ✅ Found 25 cars on page 5475
# 📄 Total scraped: 6075
#
# 🔎 Extracting page 5476 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5476&page_size=25
# ✅ Found 25 cars on page 5476
# 📄 Total scraped: 6100
#
# 🔎 Extracting page 5477 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5477&page_size=25
# ✅ Found 25 cars on page 5477
# 📄 Total scraped: 6125
#
# 🔎 Extracting page 5478 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5478&page_size=25
# ✅ Found 25 cars on page 5478
# 📄 Total scraped: 6150
#
# 🔎 Extracting page 5479 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5479&page_size=25
# ✅ Found 25 cars on page 5479
# 📄 Total scraped: 6175
#
# 🔎 Extracting page 5480 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5480&page_size=25
# ✅ Found 25 cars on page 5480
# 📄 Total scraped: 6200
#
# 🔎 Extracting page 5481 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5481&page_size=25
# ✅ Found 25 cars on page 5481
# 📄 Total scraped: 6225
#
# 🔎 Extracting page 5482 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5482&page_size=25
# ✅ Found 25 cars on page 5482
# 📄 Total scraped: 6250
#
# 🔎 Extracting page 5483 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5483&page_size=25
# ✅ Found 25 cars on page 5483
# 📄 Total scraped: 6275
#
# 🔎 Extracting page 5484 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5484&page_size=25
# ✅ Found 25 cars on page 5484
# 📄 Total scraped: 6300
#
# 🔎 Extracting page 5485 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5485&page_size=25
# ✅ Found 25 cars on page 5485
# 📄 Total scraped: 6325
#
# 🔎 Extracting page 5486 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5486&page_size=25
# ✅ Found 25 cars on page 5486
# 📄 Total scraped: 6350
#
# 🔎 Extracting page 5487 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5487&page_size=25
# ✅ Found 25 cars on page 5487
# 📄 Total scraped: 6375
#
# 🔎 Extracting page 5488 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5488&page_size=25
# ✅ Found 25 cars on page 5488
# 📄 Total scraped: 6400
#
# 🔎 Extracting page 5489 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5489&page_size=25
# ✅ Found 25 cars on page 5489
# 📄 Total scraped: 6425
#
# 🔎 Extracting page 5490 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5490&page_size=25
# ✅ Found 25 cars on page 5490
# 📄 Total scraped: 6450
#
# 🔎 Extracting page 5491 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5491&page_size=25
# ✅ Found 25 cars on page 5491
# 📄 Total scraped: 6475
#
# 🔎 Extracting page 5492 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5492&page_size=25
# ✅ Found 25 cars on page 5492
# 📄 Total scraped: 6500
#
# 🔎 Extracting page 5493 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5493&page_size=25
# ✅ Found 25 cars on page 5493
# 📄 Total scraped: 6525
#
# 🔎 Extracting page 5494 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5494&page_size=25
# ✅ Found 25 cars on page 5494
# 📄 Total scraped: 6550
#
# 🔎 Extracting page 5495 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5495&page_size=25
# ✅ Found 25 cars on page 5495
# 📄 Total scraped: 6575
#
# 🔎 Extracting page 5496 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5496&page_size=25
# ✅ Found 25 cars on page 5496
# 📄 Total scraped: 6600
#
# 🔎 Extracting page 5497 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5497&page_size=25
# ✅ Found 25 cars on page 5497
# 📄 Total scraped: 6625
#
# 🔎 Extracting page 5498 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5498&page_size=25
# ✅ Found 25 cars on page 5498
# 📄 Total scraped: 6650
#
# 🔎 Extracting page 5499 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5499&page_size=25
# ✅ Found 25 cars on page 5499
# 📄 Total scraped: 6675
#
# 🔎 Extracting page 5500 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5500&page_size=25
# ✅ Found 25 cars on page 5500
# 📄 Total scraped: 6700
#
# 🔎 Extracting page 5501 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5501&page_size=25
# ✅ Found 25 cars on page 5501
# 📄 Total scraped: 6725
#
# 🔎 Extracting page 5502 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5502&page_size=25
# ✅ Found 25 cars on page 5502
# 📄 Total scraped: 6750
#
# 🔎 Extracting page 5503 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5503&page_size=25
# ✅ Found 25 cars on page 5503
# 📄 Total scraped: 6775
#
# 🔎 Extracting page 5504 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5504&page_size=25
# ✅ Found 25 cars on page 5504
# 📄 Total scraped: 6800
#
# 🔎 Extracting page 5505 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5505&page_size=25
# ✅ Found 25 cars on page 5505
# 📄 Total scraped: 6825
#
# 🔎 Extracting page 5506 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5506&page_size=25
# ✅ Found 25 cars on page 5506
# 📄 Total scraped: 6850
#
# 🔎 Extracting page 5507 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5507&page_size=25
# ✅ Found 25 cars on page 5507
# 📄 Total scraped: 6875
#
# 🔎 Extracting page 5508 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5508&page_size=25
# ✅ Found 25 cars on page 5508
# 📄 Total scraped: 6900
#
# 🔎 Extracting page 5509 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5509&page_size=25
# ✅ Found 25 cars on page 5509
# 📄 Total scraped: 6925
#
# 🔎 Extracting page 5510 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5510&page_size=25
# ✅ Found 25 cars on page 5510
# 📄 Total scraped: 6950
#
# 🔎 Extracting page 5511 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5511&page_size=25
# ✅ Found 25 cars on page 5511
# 📄 Total scraped: 6975
#
# 🔎 Extracting page 5512 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5512&page_size=25
# ✅ Found 25 cars on page 5512
# 📄 Total scraped: 7000
#
# 🔎 Extracting page 5513 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5513&page_size=25
# ✅ Found 25 cars on page 5513
# 📄 Total scraped: 7025
#
# 🔎 Extracting page 5514 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5514&page_size=25
# ✅ Found 25 cars on page 5514
# 📄 Total scraped: 7050
#
# 🔎 Extracting page 5515 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5515&page_size=25
# ✅ Found 25 cars on page 5515
# 📄 Total scraped: 7075
#
# 🔎 Extracting page 5516 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5516&page_size=25
# ✅ Found 25 cars on page 5516
# 📄 Total scraped: 7100
#
# 🔎 Extracting page 5517 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5517&page_size=25
# ✅ Found 25 cars on page 5517
# 📄 Total scraped: 7125
#
# 🔎 Extracting page 5518 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5518&page_size=25
# ✅ Found 25 cars on page 5518
# 📄 Total scraped: 7150
#
# 🔎 Extracting page 5519 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5519&page_size=25
# ✅ Found 25 cars on page 5519
# 📄 Total scraped: 7175
#
# 🔎 Extracting page 5520 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5520&page_size=25
# ✅ Found 25 cars on page 5520
# 📄 Total scraped: 7200
#
# 🔎 Extracting page 5521 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5521&page_size=25
# ✅ Found 25 cars on page 5521
# 📄 Total scraped: 7225
#
# 🔎 Extracting page 5522 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5522&page_size=25
# ✅ Found 25 cars on page 5522
# 📄 Total scraped: 7250
#
# 🔎 Extracting page 5523 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5523&page_size=25
# ✅ Found 25 cars on page 5523
# 📄 Total scraped: 7275
#
# 🔎 Extracting page 5524 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5524&page_size=25
# ✅ Found 25 cars on page 5524
# 📄 Total scraped: 7300
#
# 🔎 Extracting page 5525 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5525&page_size=25
# ✅ Found 25 cars on page 5525
# 📄 Total scraped: 7325
#
# 🔎 Extracting page 5526 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5526&page_size=25
# ✅ Found 25 cars on page 5526
# 📄 Total scraped: 7350
#
# 🔎 Extracting page 5527 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5527&page_size=25
# ✅ Found 25 cars on page 5527
# 📄 Total scraped: 7375
#
# 🔎 Extracting page 5528 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5528&page_size=25
# ✅ Found 25 cars on page 5528
# 📄 Total scraped: 7400
#
# 🔎 Extracting page 5529 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5529&page_size=25
# ✅ Found 25 cars on page 5529
# 📄 Total scraped: 7425
#
# 🔎 Extracting page 5530 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5530&page_size=25
# ✅ Found 25 cars on page 5530
# 📄 Total scraped: 7450
#
# 🔎 Extracting page 5531 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5531&page_size=25
# ✅ Found 25 cars on page 5531
# 📄 Total scraped: 7475
#
# 🔎 Extracting page 5532 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5532&page_size=25
# ✅ Found 25 cars on page 5532
# 📄 Total scraped: 7500
#
# 🔎 Extracting page 5533 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5533&page_size=25
# ✅ Found 25 cars on page 5533
# 📄 Total scraped: 7525
#
# 🔎 Extracting page 5534 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5534&page_size=25
# ✅ Found 25 cars on page 5534
# 📄 Total scraped: 7550
#
# 🔎 Extracting page 5535 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5535&page_size=25
# ✅ Found 25 cars on page 5535
# 📄 Total scraped: 7575
#
# 🔎 Extracting page 5536 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5536&page_size=25
# ✅ Found 25 cars on page 5536
# 📄 Total scraped: 7600
#
# 🔎 Extracting page 5537 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5537&page_size=25
# ✅ Found 25 cars on page 5537
# 📄 Total scraped: 7625
#
# 🔎 Extracting page 5538 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5538&page_size=25
# ✅ Found 25 cars on page 5538
# 📄 Total scraped: 7650
#
# 🔎 Extracting page 5539 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5539&page_size=25
# ✅ Found 25 cars on page 5539
# 📄 Total scraped: 7675
#
# 🔎 Extracting page 5540 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5540&page_size=25
# ✅ Found 25 cars on page 5540
# 📄 Total scraped: 7700
#
# 🔎 Extracting page 5541 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5541&page_size=25
# ✅ Found 25 cars on page 5541
# 📄 Total scraped: 7725
#
# 🔎 Extracting page 5542 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5542&page_size=25
# ✅ Found 25 cars on page 5542
# 📄 Total scraped: 7750
#
# 🔎 Extracting page 5543 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5543&page_size=25
# ✅ Found 25 cars on page 5543
# 📄 Total scraped: 7775
#
# 🔎 Extracting page 5544 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5544&page_size=25
# ✅ Found 25 cars on page 5544
# 📄 Total scraped: 7800
#
# 🔎 Extracting page 5545 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5545&page_size=25
# ✅ Found 25 cars on page 5545
# 📄 Total scraped: 7825
#
# 🔎 Extracting page 5546 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5546&page_size=25
# ✅ Found 25 cars on page 5546
# 📄 Total scraped: 7850
#
# ...
# ✅ Found 25 cars on page 5897
# 📄 Total scraped: 16625
#
# 🔎 Extracting page 5898 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5898&page_size=25
# ✅ Found 25 cars on page 5898
# 📄 Total scraped: 16650
#
# 🔎 Extracting page 5899 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5899&page_size=25
# ✅ Found 25 cars on page 5899
# 📄 Total scraped: 16675
#
# 🔎 Extracting page 5900 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5900&page_size=25
# ✅ Found 25 cars on page 5900
# 📄 Total scraped: 16700
#
# 🔎 Extracting page 5901 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5901&page_size=25
# ✅ Found 25 cars on page 5901
# 📄 Total scraped: 16725
#
# 🔎 Extracting page 5902 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5902&page_size=25
# ✅ Found 25 cars on page 5902
# 📄 Total scraped: 16750
#
# 🔎 Extracting page 5903 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5903&page_size=25
# ✅ Found 25 cars on page 5903
# 📄 Total scraped: 16775
#
# 🔎 Extracting page 5904 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5904&page_size=25
# ✅ Found 25 cars on page 5904
# 📄 Total scraped: 16800
#
# 🔎 Extracting page 5905 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5905&page_size=25
# ✅ Found 25 cars on page 5905
# 📄 Total scraped: 16825
#
# 🔎 Extracting page 5906 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5906&page_size=25
# ✅ Found 25 cars on page 5906
# 📄 Total scraped: 16850
#
# 🔎 Extracting page 5907 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5907&page_size=25
# ✅ Found 25 cars on page 5907
# 📄 Total scraped: 16875
#
# 🔎 Extracting page 5908 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5908&page_size=25
# ✅ Found 25 cars on page 5908
# 📄 Total scraped: 16900
#
# 🔎 Extracting page 5909 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5909&page_size=25
# ✅ Found 25 cars on page 5909
# 📄 Total scraped: 16925
#
# 🔎 Extracting page 5910 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5910&page_size=25
# ✅ Found 25 cars on page 5910
# 📄 Total scraped: 16950
#
# 🔎 Extracting page 5911 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5911&page_size=25
# ✅ Found 25 cars on page 5911
# 📄 Total scraped: 16975
#
# 🔎 Extracting page 5912 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5912&page_size=25
# ✅ Found 25 cars on page 5912
# 📄 Total scraped: 17000
#
# 🔎 Extracting page 5913 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5913&page_size=25
# ✅ Found 25 cars on page 5913
# 📄 Total scraped: 17025
#
# 🔎 Extracting page 5914 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5914&page_size=25
# ✅ Found 25 cars on page 5914
# 📄 Total scraped: 17050
#
# 🔎 Extracting page 5915 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5915&page_size=25
# ✅ Found 25 cars on page 5915
# 📄 Total scraped: 17075
#
# 🔎 Extracting page 5916 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5916&page_size=25
# ✅ Found 25 cars on page 5916
# 📄 Total scraped: 17100
#
# 🔎 Extracting page 5917 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5917&page_size=25
# ✅ Found 25 cars on page 5917
# 📄 Total scraped: 17125
#
# 🔎 Extracting page 5918 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5918&page_size=25
# ✅ Found 25 cars on page 5918
# 📄 Total scraped: 17150
#
# 🔎 Extracting page 5919 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5919&page_size=25
# ✅ Found 25 cars on page 5919
# 📄 Total scraped: 17175
#
# 🔎 Extracting page 5920 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5920&page_size=25
# ✅ Found 25 cars on page 5920
# 📄 Total scraped: 17200
#
# 🔎 Extracting page 5921 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5921&page_size=25
# ✅ Found 25 cars on page 5921
# 📄 Total scraped: 17225
#
# 🔎 Extracting page 5922 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5922&page_size=25
# ✅ Found 25 cars on page 5922
# 📄 Total scraped: 17250
#
# 🔎 Extracting page 5923 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5923&page_size=25
# ✅ Found 25 cars on page 5923
# 📄 Total scraped: 17275
#
# 🔎 Extracting page 5924 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5924&page_size=25
# ✅ Found 25 cars on page 5924
# 📄 Total scraped: 17300
#
# 🔎 Extracting page 5925 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5925&page_size=25
# ✅ Found 25 cars on page 5925
# 📄 Total scraped: 17325
#
# 🔎 Extracting page 5926 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5926&page_size=25
# ✅ Found 25 cars on page 5926
# 📄 Total scraped: 17350
#
# 🔎 Extracting page 5927 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5927&page_size=25
# ✅ Found 25 cars on page 5927
# 📄 Total scraped: 17375
#
# 🔎 Extracting page 5928 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5928&page_size=25
# ✅ Found 25 cars on page 5928
# 📄 Total scraped: 17400
#
# 🔎 Extracting page 5929 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5929&page_size=25
# ✅ Found 25 cars on page 5929
# 📄 Total scraped: 17425
#
# 🔎 Extracting page 5930 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5930&page_size=25
# ✅ Found 25 cars on page 5930
# 📄 Total scraped: 17450
#
# 🔎 Extracting page 5931 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5931&page_size=25
# ✅ Found 25 cars on page 5931
# 📄 Total scraped: 17475
#
# 🔎 Extracting page 5932 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5932&page_size=25
# ✅ Found 25 cars on page 5932
# 📄 Total scraped: 17500
#
# 🔎 Extracting page 5933 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5933&page_size=25
# ✅ Found 25 cars on page 5933
# 📄 Total scraped: 17525
#
# 🔎 Extracting page 5934 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5934&page_size=25
# ✅ Found 25 cars on page 5934
# 📄 Total scraped: 17550
#
# 🔎 Extracting page 5935 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5935&page_size=25
# ✅ Found 25 cars on page 5935
# 📄 Total scraped: 17575
#
# 🔎 Extracting page 5936 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5936&page_size=25
# ✅ Found 25 cars on page 5936
# 📄 Total scraped: 17600
#
# 🔎 Extracting page 5937 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5937&page_size=25
# ✅ Found 25 cars on page 5937
# 📄 Total scraped: 17625
#
# 🔎 Extracting page 5938 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5938&page_size=25
# ✅ Found 25 cars on page 5938
# 📄 Total scraped: 17650
#
# 🔎 Extracting page 5939 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5939&page_size=25
# ✅ Found 25 cars on page 5939
# 📄 Total scraped: 17675
#
# 🔎 Extracting page 5940 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5940&page_size=25
# ✅ Found 25 cars on page 5940
# 📄 Total scraped: 17700
#
# 🔎 Extracting page 5941 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5941&page_size=25
# ✅ Found 25 cars on page 5941
# 📄 Total scraped: 17725
#
# 🔎 Extracting page 5942 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5942&page_size=25
# ✅ Found 25 cars on page 5942
# 📄 Total scraped: 17750
#
# 🔎 Extracting page 5943 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5943&page_size=25
# ✅ Found 25 cars on page 5943
# 📄 Total scraped: 17775
#
# 🔎 Extracting page 5944 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5944&page_size=25
# ✅ Found 25 cars on page 5944
# 📄 Total scraped: 17800
#
# 🔎 Extracting page 5945 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5945&page_size=25
# ✅ Found 25 cars on page 5945
# 📄 Total scraped: 17825
#
# 🔎 Extracting page 5946 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5946&page_size=25
# ✅ Found 25 cars on page 5946
# 📄 Total scraped: 17850
#
# 🔎 Extracting page 5947 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5947&page_size=25
# ✅ Found 25 cars on page 5947
# 📄 Total scraped: 17875
#
# 🔎 Extracting page 5948 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5948&page_size=25
# ✅ Found 25 cars on page 5948
# 📄 Total scraped: 17900
#
# 🔎 Extracting page 5949 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5949&page_size=25
# ✅ Found 25 cars on page 5949
# 📄 Total scraped: 17925
#
# 🔎 Extracting page 5950 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5950&page_size=25
# ✅ Found 25 cars on page 5950
# 📄 Total scraped: 17950
#
# 🔎 Extracting page 5951 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5951&page_size=25
# ✅ Found 25 cars on page 5951
# 📄 Total scraped: 17975
#
# 🔎 Extracting page 5952 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5952&page_size=25
# ✅ Found 25 cars on page 5952
# 📄 Total scraped: 18000
#
# 🔎 Extracting page 5953 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5953&page_size=25
# ✅ Found 25 cars on page 5953
# 📄 Total scraped: 18025
#
# 🔎 Extracting page 5954 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5954&page_size=25
# ✅ Found 25 cars on page 5954
# 📄 Total scraped: 18050
#
# 🔎 Extracting page 5955 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5955&page_size=25
# ✅ Found 25 cars on page 5955
# 📄 Total scraped: 18075
#
# 🔎 Extracting page 5956 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5956&page_size=25
# ✅ Found 25 cars on page 5956
# 📄 Total scraped: 18100
#
# 🔎 Extracting page 5957 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5957&page_size=25
# ✅ Found 25 cars on page 5957
# 📄 Total scraped: 18125
#
# 🔎 Extracting page 5958 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5958&page_size=25
# ✅ Found 25 cars on page 5958
# 📄 Total scraped: 18150
#
# 🔎 Extracting page 5959 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5959&page_size=25
# ✅ Found 25 cars on page 5959
# 📄 Total scraped: 18175
#
# 🔎 Extracting page 5960 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5960&page_size=25
# ✅ Found 25 cars on page 5960
# 📄 Total scraped: 18200
#
# 🔎 Extracting page 5961 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5961&page_size=25
# ✅ Found 25 cars on page 5961
# 📄 Total scraped: 18225
#
# 🔎 Extracting page 5962 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5962&page_size=25
# ✅ Found 25 cars on page 5962
# 📄 Total scraped: 18250
#
# 🔎 Extracting page 5963 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5963&page_size=25
# ✅ Found 25 cars on page 5963
# 📄 Total scraped: 18275
#
# 🔎 Extracting page 5964 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5964&page_size=25
# ✅ Found 25 cars on page 5964
# 📄 Total scraped: 18300
#
# 🔎 Extracting page 5965 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5965&page_size=25
# ✅ Found 25 cars on page 5965
# 📄 Total scraped: 18325
#
# 🔎 Extracting page 5966 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5966&page_size=25
# ✅ Found 25 cars on page 5966
# 📄 Total scraped: 18350
#
# 🔎 Extracting page 5967 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5967&page_size=25
# ✅ Found 25 cars on page 5967
# 📄 Total scraped: 18375
#
# 🔎 Extracting page 5968 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5968&page_size=25
# ✅ Found 25 cars on page 5968
# 📄 Total scraped: 18400
#
# 🔎 Extracting page 5969 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5969&page_size=25
# ✅ Found 25 cars on page 5969
# 📄 Total scraped: 18425
#
# 🔎 Extracting page 5970 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5970&page_size=25
# ✅ Found 25 cars on page 5970
# 📄 Total scraped: 18450
#
# 🔎 Extracting page 5971 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5971&page_size=25
# ✅ Found 25 cars on page 5971
# 📄 Total scraped: 18475
#
# 🔎 Extracting page 5972 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5972&page_size=25
# ✅ Found 25 cars on page 5972
# 📄 Total scraped: 18500
#
# 🔎 Extracting page 5973 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5973&page_size=25
# ✅ Found 25 cars on page 5973
# 📄 Total scraped: 18525
#
# 🔎 Extracting page 5974 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5974&page_size=25
# ✅ Found 25 cars on page 5974
# 📄 Total scraped: 18550
#
# 🔎 Extracting page 5975 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5975&page_size=25
# ✅ Found 25 cars on page 5975
# 📄 Total scraped: 18575
#
# 🔎 Extracting page 5976 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5976&page_size=25
# ✅ Found 25 cars on page 5976
# 📄 Total scraped: 18600
#
# 🔎 Extracting page 5977 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5977&page_size=25
# ✅ Found 25 cars on page 5977
# 📄 Total scraped: 18625
#
# 🔎 Extracting page 5978 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5978&page_size=25
# ✅ Found 25 cars on page 5978
# 📄 Total scraped: 18650
#
# 🔎 Extracting page 5979 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5979&page_size=25
# ✅ Found 25 cars on page 5979
# 📄 Total scraped: 18675
#
# 🔎 Extracting page 5980 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5980&page_size=25
# ✅ Found 25 cars on page 5980
# 📄 Total scraped: 18700
#
# 🔎 Extracting page 5981 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5981&page_size=25
# ✅ Found 25 cars on page 5981
# 📄 Total scraped: 18725
#
# 🔎 Extracting page 5982 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5982&page_size=25
# ✅ Found 25 cars on page 5982
# 📄 Total scraped: 18750
#
# 🔎 Extracting page 5983 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5983&page_size=25
# ✅ Found 25 cars on page 5983
# 📄 Total scraped: 18775
#
# 🔎 Extracting page 5984 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5984&page_size=25
# ✅ Found 25 cars on page 5984
# 📄 Total scraped: 18800
#
# 🔎 Extracting page 5985 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5985&page_size=25
# ✅ Found 25 cars on page 5985
# 📄 Total scraped: 18825
#
# 🔎 Extracting page 5986 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5986&page_size=25
# ✅ Found 25 cars on page 5986
# 📄 Total scraped: 18850
#
# 🔎 Extracting page 5987 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5987&page_size=25
# ✅ Found 25 cars on page 5987
# 📄 Total scraped: 18875
#
# 🔎 Extracting page 5988 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5988&page_size=25
# ✅ Found 25 cars on page 5988
# 📄 Total scraped: 18900
#
# 🔎 Extracting page 5989 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5989&page_size=25
# ✅ Found 25 cars on page 5989
# 📄 Total scraped: 18925
#
# 🔎 Extracting page 5990 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5990&page_size=25
# ✅ Found 25 cars on page 5990
# 📄 Total scraped: 18950
#
# 🔎 Extracting page 5991 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5991&page_size=25
# ✅ Found 25 cars on page 5991
# 📄 Total scraped: 18975
#
# 🔎 Extracting page 5992 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5992&page_size=25
# ✅ Found 25 cars on page 5992
# 📄 Total scraped: 19000
#
# 🔎 Extracting page 5993 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5993&page_size=25
# ✅ Found 25 cars on page 5993
# 📄 Total scraped: 19025
#
# 🔎 Extracting page 5994 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5994&page_size=25
# ✅ Found 25 cars on page 5994
# 📄 Total scraped: 19050
#
# 🔎 Extracting page 5995 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5995&page_size=25
# ✅ Found 25 cars on page 5995
# 📄 Total scraped: 19075
#
# 🔎 Extracting page 5996 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5996&page_size=25
# ✅ Found 25 cars on page 5996
# 📄 Total scraped: 19100
#
# 🔎 Extracting page 5997 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5997&page_size=25
# ✅ Found 25 cars on page 5997
# 📄 Total scraped: 19125
#
# 🔎 Extracting page 5998 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5998&page_size=25
# ✅ Found 25 cars on page 5998
# 📄 Total scraped: 19150
#
# 🔎 Extracting page 5999 - https://www.carlist.my/cars-for-sale/malaysia?page_number=5999&page_size=25
# ✅ Found 25 cars on page 5999
# 📄 Total scraped: 19175
#
# 🔎 Extracting page 6000 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6000&page_size=25
# ✅ Found 25 cars on page 6000
# 📄 Total scraped: 19200

# %% [markdown]
# # 6. Saving Data to CSV
# The script checks if any car listings were successfully scraped.
#
# It opens the output CSV file for writing and uses csv.DictWriter to write the data.
#
# The writeheader() method writes the column headers, while writerows() writes the data for all the car listings.

# %%
# Save the extracted data to a CSV file
if car_listings:
    with open(output_file, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=car_listings[0].keys())
        writer.writeheader()  # Write the column headers
        writer.writerows(car_listings)  # Write the car listings data
    print(f"\n✅ Saved {len(car_listings)} cars to '{output_file}'")
else:
    print("\n⚠️ No car listings found.")
# Out:
# ✅ Saved 19200 cars to 'D:/camily_carlist_listings_1.csv'

# %% [markdown]
# # 7. Calculate Total Execution Time
# At the end of the script, after all scraping activities and file-saving operations, the following code is added to record the end time and calculate the total execution time:

# %%
# End time and elapsed time calculation
end_time = time.time()
execution_time = end_time - start_time
print(f"\n🕒 Total execution time: {execution_time:.2f} seconds")
# Out:
# 🕒 Total execution time: 2934.52 seconds

# %% [markdown]
# # 8. Conclusion
# The script efficiently scrapes car listings from Carlist.my, extracting both HTML and JSON data, and saves it to a CSV file for further use. This process includes handling missing data, extracting structured information, and respecting website policies by adding a delay between requests.

# %% [markdown]
# # Full Code

# %% [markdown]
# ```python
# import urllib.request
# from bs4 import BeautifulSoup, NavigableString
# import csv
# import time
# import json
#
# # Configuration
# base_url = "https://www.carlist.my/cars-for-sale/malaysia?page_number={}&page_size=25"
# start_page = 5233    # Starting page number to scrape
# end_page = 6000      # Ending page number to scrape
# car_listings = []  # List to store car listings data
#
# output_file = 'D:/camily_carlist_listings_1.csv'
#
# # Get HTML attribute or empty string if attribute doesn't exist
# def get_attr(element, attr_name):
#     return element.get(attr_name, '') if element else ''
#
# # Get the first text node inside a <div> (ignores non-text elements)
# def get_first_text_node(div):
#     for node in div.contents if div else []:
#         if isinstance(node, NavigableString) and node.strip():
#             return node
#     return ''  # Return empty string if no text node is found
#
# # Extract raw mileage information from the article (after the meter icon)
# def get_mileage(article):
#     icon = article.find('i', class_='icon--meter')  # Find meter icon
#     return str(icon.next_sibling) if icon and icon.next_sibling else ''  # Return mileage text
#
# # Extract raw location information from the article (after the location icon)
# def get_location(article):
#     icon = article.find('i', class_='icon--location')  # Find location icon
#     if not icon:
#         return ''
#     text = ''
#     for sib in icon.next_siblings:  # Loop through siblings after icon
#         if isinstance(sib, NavigableString):
#             text += str(sib)
#         elif getattr(sib, 'name', None) == 'span':
#             text += sib.get_text()
#         else:
#             break
#     return text  # Return extracted location text
#
# # Pull JSON-LD block containing the car listings from the page
# def extract_json_ld(soup):
#     for script in soup.find_all('script', type='application/ld+json'):
#         try:
#             data = json.loads(script.string)  # Parse the JSON-LD data
#             if isinstance(data, list):
#                 for d in data:
#                     if 'itemListElement' in d:
#                         return d['itemListElement']  # Return list of car listings
#         except:
#             continue
#     return None  # Return None if no valid JSON-LD is found
#
# # Start time
# start_time = time.time()
#
# # Main scraping loop
# for page_num in range(start_page, end_page + 1):
#     url = base_url.format(page_num)  # Generate URL for the current page
#     print(f"\n🔎 Extracting page {page_num} - {url}")
#
#     # Load the page and parse it with BeautifulSoup
#     req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
#     html = urllib.request.urlopen(req).read()
#     soup = BeautifulSoup(html, 'html.parser')
#
#     # Find all articles (car listings) and extract JSON-LD data
#     articles = soup.find_all('article', class_='listing')
#     ld_json = extract_json_ld(soup)
#     if not ld_json:
#         print("⚠️ No JSON-LD found on this page.")
#         continue
#
#     page_count = 0
#     # Loop through articles and corresponding JSON-LD data
#     for article, item in zip(articles, ld_json):
#         car = item['item']  # Extract JSON details for the car
#
#         # Extract fields from the <article> element’s attributes (HTML-based fields)
#         name = get_attr(article, 'data-title')
#         brand = get_attr(article, 'data-make')
#         model = get_attr(article, 'data-model')
#         body = get_attr(article, 'data-body-type')
#         transmission = get_attr(article, 'data-transmission')
#         installment = get_attr(article, 'data-installment')
#
#         # Extract exactly what is displayed on the page (visible text-based fields)
#         mileage = get_mileage(article)
#         sales_channel = get_first_text_node(article.find('div', class_='listing__spec--dealer'))
#         location = get_location(article)
#
#         # Extract additional fields from the JSON-LD data
#         year = car.get('vehicleModelDate', '')
#         fuel = car.get('fuelType', '')
#         color = car.get('color', '')
#         price = car.get('offers', {}).get('price', '')
#         condition = car.get('itemCondition', '')
#         seats = car.get('seatingCapacity', '')
#
#         # Append the extracted data to the car_listings list
#         car_listings.append({
#             'Car Name': name,
#             'Car Brand': brand,
#             'Car Model': model,
#             'Manufacture Year': year,
#             'Body Type': body,
#             'Fuel Type': fuel,
#             'Mileage': mileage,
#             'Transmission': transmission,
#             'Color': color,
#             'Price': price,
#             'Installment': installment,
#             'Condition': condition,
#             'Seating Capacity': seats,
#             'Location': location,
#             'Sales Channel': sales_channel
#         })
#         page_count += 1
#
#     print(f"✅ Found {page_count} cars on page {page_num}")
#     print(f"📄 Total scraped: {len(car_listings)}")
#     time.sleep(2)  # Sleep to avoid making too many requests in a short time
#
# # Save the extracted data to a CSV file
# if car_listings:
#     with open(output_file, 'w', newline='', encoding='utf-8') as f:
#         writer = csv.DictWriter(f, fieldnames=car_listings[0].keys())
#         writer.writeheader()  # Write the column headers
#         writer.writerows(car_listings)  # Write the car listings data
#     print(f"\n✅ Saved {len(car_listings)} cars to '{output_file}'")
# else:
#     print("\n⚠️ No car listings found.")
#
# # End time and elapsed time calculation
# end_time = time.time()
# execution_time = end_time - start_time
# print(f"\n🕒 Total execution time: {execution_time:.2f} seconds")
# ```
