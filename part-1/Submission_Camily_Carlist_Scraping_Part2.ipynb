# %% [markdown]
# # **Web Scrapping (BeautifulSoup + URLlib) Part 2**

# %% [markdown]
# **Group:** Group 1 \
# **Name:** Camily Tang Jia Lei \
# **Matrics. No:** A22EC0039
#
# **Group Members:**
#   1.  Marcus Joey Sayner (A22EC0193)
#   2. Muhammad Luqman Hakim bin Mohd Rizaudin (A22EC0086)
#   3. Camily Tang Jia Lei (A22EC0039)
#   4. Goh Jing Yang (A22EC0052)
#
# **Objective:**:
#   The objective of this project is to scrape car listings from Carlist.my, focusing on extracting key details such as car name, brand, model, price, mileage, and more. The extracted data is then saved in a CSV file for further analysis and potential use in a car market analysis.

# %% [markdown]
# # 1. Importing Libraries
# The first step in this project is to import the necessary Python libraries. These libraries are used for fetching the webpage, parsing the HTML content, and handling data.
#
# *   **urllib.request:** This module is used for sending HTTP requests and fetching the HTML content of web pages. We use it to download the webpage’s HTML content.
# *   **BeautifulSoup:** A powerful library used to parse HTML and XML documents. It provides methods to navigate and search the parse tree, making it easier to extract specific elements from the page.
# *   **csv:** A built-in Python module for reading from and writing to CSV files. It's used here to store the scraped data in a structured tabular format.
# *   **time:** The time module is used to add delays between requests, helping to avoid overwhelming the website with too many requests in a short period.
# *   **json:** This module is used for parsing JSON data. Since the car listings are embedded in a JSON-LD script, this module allows us to extract and handle that data effectively.

# %%
import urllib.request
from bs4 import BeautifulSoup, NavigableString
import csv
import time
import json

# %% [markdown]
# ## 2. Configuration
# Here, we set up the configuration for the scraping process, including the base URL for the car listings and the page range that we want to scrape. We also prepare an empty list to store the car listings and specify the output file name.
#
#
#
# *   **base_url:** The base URL is a template for the car listings pages on Carlist.my. The {} placeholder is replaced with the current page number during the scraping process. The page size is set to 25 listings per page.
# *   **start_page and end_page:** These variables define the range of pages to scrape. In this case, the scraper will fetch pages 1 and 2.
# *   **car_listings:** This list will store the data extracted from each car listing. Each listing will be appended to this list as a dictionary.
# *   **output_file:** The name of the CSV file where the scraped data will be saved.

# %%
# Configuration
base_url = "https://www.carlist.my/cars-for-sale/malaysia?page_number={}&page_size=25"
start_page = 6001    # Starting page number to scrape 
end_page = 6977      # Ending page number to scrape 6977
car_listings = []  # List to store car listings data

output_file = 'D:/camily_carlist_listings_2.csv'

# %% [markdown]
# # 3. Helper Functions for Data Extraction
# Several helper functions are defined to extract specific details from the HTML content and embedded JSON data.

# %% [markdown]
# 3.1 Get HTML Attributes <br>
# This function retrieves the value of a specified HTML attribute from a given element. If the attribute is not found, it returns an empty string.

# %%
# Get HTML attribute or empty string if attribute doesn't exist
def get_attr(element, attr_name):
    return element.get(attr_name, '') if element else ''

# %% [markdown]
# 3.2 Extract the First Text Node <br>
# This function extracts the first visible text node inside a div element. It ignores non-text elements like tags and returns only the first piece of text content.

# %%
# Get the first text node inside a <div> (ignores non-text elements)
def get_first_text_node(div):
    for node in div.contents if div else []:
        if isinstance(node, NavigableString) and node.strip():
            return node
    return ''  # Return empty string if no text node is found

# %% [markdown]
# 3.3 Extract Mileage Data <br>
# This function searches for the meter icon in each car listing and retrieves the mileage information associated with it. If the icon is found, it returns the text next to it; otherwise, it returns an empty string.

# %%
# Extract raw mileage information from the article (after the meter icon)
def get_mileage(article):
    icon = article.find('i', class_='icon--meter')  # Find meter icon
    return str(icon.next_sibling) if icon and icon.next_sibling else ''  # Return mileage text

# %% [markdown]
# 3.4 Extract Location Data<br>
# This function retrieves the location information for each car listing. It searches for the location icon and extracts the text that follows it.

# %%
# Extract raw location information from the article (after the location icon)
def get_location(article):
    icon = article.find('i', class_='icon--location')  # Find location icon
    if not icon:
        return ''
    text = ''
    for sib in icon.next_siblings:  # Loop through siblings after icon
        if isinstance(sib, NavigableString):
            text += str(sib)
        elif getattr(sib, 'name', None) == 'span':
            text += sib.get_text()
        else:
            break
    return text  # Return extracted location text

# %% [markdown]
# 3.5 Extract JSON-LD Data <br>
# This function extracts the embedded JSON-LD data from the webpage. JSON-LD is used to represent structured data about the car listings. The function looks for the script tag containing this data, parses it, and returns the list of car listings.

# %%
# Pull JSON-LD block containing the car listings from the page
def extract_json_ld(soup):
    for script in soup.find_all('script', type='application/ld+json'):
        try:
            data = json.loads(script.string)  # Parse the JSON-LD data
            if isinstance(data, list):
                for d in data:
                    if 'itemListElement' in d:
                        return d['itemListElement']  # Return list of car listings
        except:
            continue
    return None  # Return None if no valid JSON-LD is found

# %% [markdown]
# # 4. Tracking Execution Time
# This line captures the current time (in seconds) before the main scraping loop begins. The time.time() function returns the time as a floating-point number. By capturing the start time, we can later calculate the total execution time of the script. This helps in assessing the efficiency of the scraping process, particularly useful when scraping multiple pages or large amounts of data. It allows for performance optimization and comparison with future improvements or different approaches.

# %%
# Start time
start_time = time.time()

# %% [markdown]
# # 5. Main Scraping Loop
# In this section, the main scraping process is performed. We iterate over the specified pages and extract the relevant car listing data.

# %%
# Main scraping loop
for page_num in range(start_page, end_page + 1):
    url = base_url.format(page_num)  # Generate URL for the current page
    print(f"\n🔎 Extracting page {page_num} - {url}")

    # Load the page and parse it with BeautifulSoup
    req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
    html = urllib.request.urlopen(req).read()
    soup = BeautifulSoup(html, 'html.parser')

    # Find all articles (car listings) and extract JSON-LD data
    articles = soup.find_all('article', class_='listing')
    ld_json = extract_json_ld(soup)
    if not ld_json:
        print("⚠️ No JSON-LD found on this page.")
        continue

    page_count = 0
    # Loop through articles and corresponding JSON-LD data
    for article, item in zip(articles, ld_json):
        car = item['item']  # Extract JSON details for the car

        # Extract fields from the <article> element’s attributes (HTML-based fields)
        name = get_attr(article, 'data-title')
        brand = get_attr(article, 'data-make')
        model = get_attr(article, 'data-model')
        body = get_attr(article, 'data-body-type')
        transmission = get_attr(article, 'data-transmission')
        installment = get_attr(article, 'data-installment')

        # Extract exactly what is displayed on the page (visible text-based fields)
        mileage = get_mileage(article)
        sales_channel = get_first_text_node(article.find('div', class_='listing__spec--dealer'))
        location = get_location(article)

        # Extract additional fields from the JSON-LD data
        year = car.get('vehicleModelDate', '')
        fuel = car.get('fuelType', '')
        color = car.get('color', '')
        price = car.get('offers', {}).get('price', '')
        condition = car.get('itemCondition', '')
        seats = car.get('seatingCapacity', '')

        # Append the extracted data to the car_listings list
        car_listings.append({
            'Car Name': name,
            'Car Brand': brand,
            'Car Model': model,
            'Manufacture Year': year,
            'Body Type': body,
            'Fuel Type': fuel,
            'Mileage': mileage,
            'Transmission': transmission,
            'Color': color,
            'Price': price,
            'Installment': installment,
            'Condition': condition,
            'Seating Capacity': seats,
            'Location': location,
            'Sales Channel': sales_channel
        })
        page_count += 1

    print(f"✅ Found {page_count} cars on page {page_num}")
    print(f"📄 Total scraped: {len(car_listings)}")
    time.sleep(2)  # Sleep to avoid making too many requests in a short time
# Out:
# 🔎 Extracting page 6001 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6001&page_size=25
# ✅ Found 25 cars on page 6001
# 📄 Total scraped: 25
#
# 🔎 Extracting page 6002 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6002&page_size=25
# ✅ Found 25 cars on page 6002
# 📄 Total scraped: 50
#
# 🔎 Extracting page 6003 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6003&page_size=25
# ✅ Found 25 cars on page 6003
# 📄 Total scraped: 75
#
# 🔎 Extracting page 6004 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6004&page_size=25
# ✅ Found 25 cars on page 6004
# 📄 Total scraped: 100
#
# 🔎 Extracting page 6005 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6005&page_size=25
# ✅ Found 25 cars on page 6005
# 📄 Total scraped: 125
#
# 🔎 Extracting page 6006 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6006&page_size=25
# ✅ Found 25 cars on page 6006
# 📄 Total scraped: 150
#
# 🔎 Extracting page 6007 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6007&page_size=25
# ✅ Found 25 cars on page 6007
# 📄 Total scraped: 175
#
# 🔎 Extracting page 6008 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6008&page_size=25
# ✅ Found 25 cars on page 6008
# 📄 Total scraped: 200
#
# 🔎 Extracting page 6009 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6009&page_size=25
# ✅ Found 25 cars on page 6009
# 📄 Total scraped: 225
#
# 🔎 Extracting page 6010 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6010&page_size=25
# ✅ Found 25 cars on page 6010
# 📄 Total scraped: 250
#
# 🔎 Extracting page 6011 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6011&page_size=25
# ✅ Found 25 cars on page 6011
# 📄 Total scraped: 275
#
# 🔎 Extracting page 6012 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6012&page_size=25
# ✅ Found 25 cars on page 6012
# 📄 Total scraped: 300
#
# 🔎 Extracting page 6013 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6013&page_size=25
# ✅ Found 25 cars on page 6013
# 📄 Total scraped: 325
#
# 🔎 Extracting page 6014 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6014&page_size=25
# ✅ Found 25 cars on page 6014
# 📄 Total scraped: 350
#
# 🔎 Extracting page 6015 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6015&page_size=25
# ✅ Found 25 cars on page 6015
# 📄 Total scraped: 375
#
# 🔎 Extracting page 6016 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6016&page_size=25
# ✅ Found 25 cars on page 6016
# 📄 Total scraped: 400
#
# 🔎 Extracting page 6017 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6017&page_size=25
# ✅ Found 25 cars on page 6017
# 📄 Total scraped: 425
#
# 🔎 Extracting page 6018 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6018&page_size=25
# ✅ Found 25 cars on page 6018
# 📄 Total scraped: 450
#
# 🔎 Extracting page 6019 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6019&page_size=25
# ✅ Found 25 cars on page 6019
# 📄 Total scraped: 475
#
# 🔎 Extracting page 6020 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6020&page_size=25
# ✅ Found 25 cars on page 6020
# 📄 Total scraped: 500
#
# 🔎 Extracting page 6021 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6021&page_size=25
# ✅ Found 25 cars on page 6021
# 📄 Total scraped: 525
#
# 🔎 Extracting page 6022 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6022&page_size=25
# ✅ Found 25 cars on page 6022
# 📄 Total scraped: 550
#
# 🔎 Extracting page 6023 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6023&page_size=25
# ✅ Found 25 cars on page 6023
# 📄 Total scraped: 575
#
# 🔎 Extracting page 6024 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6024&page_size=25
# ✅ Found 25 cars on page 6024
# 📄 Total scraped: 600
#
# 🔎 Extracting page 6025 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6025&page_size=25
# ✅ Found 25 cars on page 6025
# 📄 Total scraped: 625
#
# 🔎 Extracting page 6026 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6026&page_size=25
# ✅ Found 25 cars on page 6026
# 📄 Total scraped: 650
#
# 🔎 Extracting page 6027 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6027&page_size=25
# ✅ Found 25 cars on page 6027
# 📄 Total scraped: 675
#
# 🔎 Extracting page 6028 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6028&page_size=25
# ✅ Found 25 cars on page 6028
# 📄 Total scraped: 700
#
# 🔎 Extracting page 6029 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6029&page_size=25
# ✅ Found 25 cars on page 6029
# 📄 Total scraped: 725
#
# 🔎 Extracting page 6030 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6030&page_size=25
# ✅ Found 25 cars on page 6030
# 📄 Total scraped: 750
#
# 🔎 Extracting page 6031 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6031&page_size=25
# ✅ Found 25 cars on page 6031
# 📄 Total scraped: 775
#
# 🔎 Extracting page 6032 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6032&page_size=25
# ✅ Found 25 cars on page 6032
# 📄 Total scraped: 800
#
# 🔎 Extracting page 6033 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6033&page_size=25
# ✅ Found 25 cars on page 6033
# 📄 Total scraped: 825
#
# 🔎 Extracting page 6034 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6034&page_size=25
# ✅ Found 25 cars on page 6034
# 📄 Total scraped: 850
#
# 🔎 Extracting page 6035 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6035&page_size=25
# ✅ Found 25 cars on page 6035
# 📄 Total scraped: 875
#
# 🔎 Extracting page 6036 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6036&page_size=25
# ✅ Found 25 cars on page 6036
# 📄 Total scraped: 900
#
# 🔎 Extracting page 6037 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6037&page_size=25
# ✅ Found 25 cars on page 6037
# 📄 Total scraped: 925
#
# 🔎 Extracting page 6038 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6038&page_size=25
# ✅ Found 25 cars on page 6038
# 📄 Total scraped: 950
#
# 🔎 Extracting page 6039 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6039&page_size=25
# ✅ Found 25 cars on page 6039
# 📄 Total scraped: 975
#
# 🔎 Extracting page 6040 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6040&page_size=25
# ✅ Found 25 cars on page 6040
# 📄 Total scraped: 1000
#
# 🔎 Extracting page 6041 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6041&page_size=25
# ✅ Found 25 cars on page 6041
# 📄 Total scraped: 1025
#
# 🔎 Extracting page 6042 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6042&page_size=25
# ✅ Found 25 cars on page 6042
# 📄 Total scraped: 1050
#
# 🔎 Extracting page 6043 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6043&page_size=25
# ✅ Found 25 cars on page 6043
# 📄 Total scraped: 1075
#
# 🔎 Extracting page 6044 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6044&page_size=25
# ✅ Found 25 cars on page 6044
# 📄 Total scraped: 1100
#
# 🔎 Extracting page 6045 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6045&page_size=25
# ✅ Found 25 cars on page 6045
# 📄 Total scraped: 1125
#
# 🔎 Extracting page 6046 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6046&page_size=25
# ✅ Found 25 cars on page 6046
# 📄 Total scraped: 1150
#
# 🔎 Extracting page 6047 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6047&page_size=25
# ✅ Found 25 cars on page 6047
# 📄 Total scraped: 1175
#
# 🔎 Extracting page 6048 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6048&page_size=25
# ✅ Found 25 cars on page 6048
# 📄 Total scraped: 1200
#
# 🔎 Extracting page 6049 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6049&page_size=25
# ✅ Found 25 cars on page 6049
# 📄 Total scraped: 1225
#
# 🔎 Extracting page 6050 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6050&page_size=25
# ✅ Found 25 cars on page 6050
# 📄 Total scraped: 1250
#
# 🔎 Extracting page 6051 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6051&page_size=25
# ✅ Found 25 cars on page 6051
# 📄 Total scraped: 1275
#
# 🔎 Extracting page 6052 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6052&page_size=25
# ✅ Found 25 cars on page 6052
# 📄 Total scraped: 1300
#
# 🔎 Extracting page 6053 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6053&page_size=25
# ✅ Found 25 cars on page 6053
# 📄 Total scraped: 1325
#
# 🔎 Extracting page 6054 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6054&page_size=25
# ✅ Found 25 cars on page 6054
# 📄 Total scraped: 1350
#
# 🔎 Extracting page 6055 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6055&page_size=25
# ✅ Found 25 cars on page 6055
# 📄 Total scraped: 1375
#
# 🔎 Extracting page 6056 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6056&page_size=25
# ✅ Found 25 cars on page 6056
# 📄 Total scraped: 1400
#
# 🔎 Extracting page 6057 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6057&page_size=25
# ✅ Found 25 cars on page 6057
# 📄 Total scraped: 1425
#
# 🔎 Extracting page 6058 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6058&page_size=25
# ✅ Found 25 cars on page 6058
# 📄 Total scraped: 1450
#
# 🔎 Extracting page 6059 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6059&page_size=25
# ✅ Found 25 cars on page 6059
# 📄 Total scraped: 1475
#
# 🔎 Extracting page 6060 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6060&page_size=25
# ✅ Found 25 cars on page 6060
# 📄 Total scraped: 1500
#
# 🔎 Extracting page 6061 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6061&page_size=25
# ✅ Found 25 cars on page 6061
# 📄 Total scraped: 1525
#
# 🔎 Extracting page 6062 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6062&page_size=25
# ✅ Found 25 cars on page 6062
# 📄 Total scraped: 1550
#
# 🔎 Extracting page 6063 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6063&page_size=25
# ✅ Found 25 cars on page 6063
# 📄 Total scraped: 1575
#
# 🔎 Extracting page 6064 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6064&page_size=25
# ✅ Found 25 cars on page 6064
# 📄 Total scraped: 1600
#
# 🔎 Extracting page 6065 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6065&page_size=25
# ✅ Found 25 cars on page 6065
# 📄 Total scraped: 1625
#
# 🔎 Extracting page 6066 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6066&page_size=25
# ✅ Found 25 cars on page 6066
# 📄 Total scraped: 1650
#
# 🔎 Extracting page 6067 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6067&page_size=25
# ✅ Found 25 cars on page 6067
# 📄 Total scraped: 1675
#
# 🔎 Extracting page 6068 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6068&page_size=25
# ✅ Found 25 cars on page 6068
# 📄 Total scraped: 1700
#
# 🔎 Extracting page 6069 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6069&page_size=25
# ✅ Found 25 cars on page 6069
# 📄 Total scraped: 1725
#
# 🔎 Extracting page 6070 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6070&page_size=25
# ✅ Found 25 cars on page 6070
# 📄 Total scraped: 1750
#
# 🔎 Extracting page 6071 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6071&page_size=25
# ✅ Found 25 cars on page 6071
# 📄 Total scraped: 1775
#
# 🔎 Extracting page 6072 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6072&page_size=25
# ✅ Found 25 cars on page 6072
# 📄 Total scraped: 1800
#
# 🔎 Extracting page 6073 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6073&page_size=25
# ✅ Found 25 cars on page 6073
# 📄 Total scraped: 1825
#
# 🔎 Extracting page 6074 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6074&page_size=25
# ✅ Found 25 cars on page 6074
# 📄 Total scraped: 1850
#
# 🔎 Extracting page 6075 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6075&page_size=25
# ✅ Found 25 cars on page 6075
# 📄 Total scraped: 1875
#
# 🔎 Extracting page 6076 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6076&page_size=25
# ✅ Found 25 cars on page 6076
# 📄 Total scraped: 1900
#
# 🔎 Extracting page 6077 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6077&page_size=25
# ✅ Found 25 cars on page 6077
# 📄 Total scraped: 1925
#
# 🔎 Extracting page 6078 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6078&page_size=25
# ✅ Found 25 cars on page 6078
# 📄 Total scraped: 1950
#
# 🔎 Extracting page 6079 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6079&page_size=25
# ✅ Found 25 cars on page 6079
# 📄 Total scraped: 1975
#
# 🔎 Extracting page 6080 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6080&page_size=25
# ✅ Found 25 cars on page 6080
# 📄 Total scraped: 2000
#
# 🔎 Extracting page 6081 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6081&page_size=25
# ✅ Found 25 cars on page 6081
# 📄 Total scraped: 2025
#
# 🔎 Extracting page 6082 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6082&page_size=25
# ✅ Found 25 cars on page 6082
# 📄 Total scraped: 2050
#
# 🔎 Extracting page 6083 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6083&page_size=25
# ✅ Found 25 cars on page 6083
# 📄 Total scraped: 2075
#
# 🔎 Extracting page 6084 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6084&page_size=25
# ✅ Found 25 cars on page 6084
# 📄 Total scraped: 2100
#
# 🔎 Extracting page 6085 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6085&page_size=25
# ✅ Found 25 cars on page 6085
# 📄 Total scraped: 2125
#
# 🔎 Extracting page 6086 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6086&page_size=25
# ✅ Found 25 cars on page 6086
# 📄 Total scraped: 2150
#
# 🔎 Extracting page 6087 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6087&page_size=25
# ✅ Found 25 cars on page 6087
# 📄 Total scraped: 2175
#
# 🔎 Extracting page 6088 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6088&page_size=25
# ✅ Found 25 cars on page 6088
# 📄 Total scraped: 2200
#
# 🔎 Extracting page 6089 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6089&page_size=25
# ✅ Found 25 cars on page 6089
# 📄 Total scraped: 2225
#
# 🔎 Extracting page 6090 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6090&page_size=25
# ✅ Found 25 cars on page 6090
# 📄 Total scraped: 2250
#
# 🔎 Extracting page 6091 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6091&page_size=25
# ✅ Found 25 cars on page 6091
# 📄 Total scraped: 2275
#
# 🔎 Extracting page 6092 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6092&page_size=25
# ✅ Found 25 cars on page 6092
# 📄 Total scraped: 2300
#
# 🔎 Extracting page 6093 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6093&page_size=25
# ✅ Found 25 cars on page 6093
# 📄 Total scraped: 2325
#
# 🔎 Extracting page 6094 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6094&page_size=25
# ✅ Found 25 cars on page 6094
# 📄 Total scraped: 2350
#
# 🔎 Extracting page 6095 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6095&page_size=25
# ✅ Found 25 cars on page 6095
# 📄 Total scraped: 2375
#
# 🔎 Extracting page 6096 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6096&page_size=25
# ✅ Found 25 cars on page 6096
# 📄 Total scraped: 2400
#
# 🔎 Extracting page 6097 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6097&page_size=25
# ✅ Found 25 cars on page 6097
# 📄 Total scraped: 2425
#
# 🔎 Extracting page 6098 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6098&page_size=25
# ✅ Found 25 cars on page 6098
# 📄 Total scraped: 2450
#
# 🔎 Extracting page 6099 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6099&page_size=25
# ✅ Found 25 cars on page 6099
# 📄 Total scraped: 2475
#
# 🔎 Extracting page 6100 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6100&page_size=25
# ✅ Found 25 cars on page 6100
# 📄 Total scraped: 2500
#
# 🔎 Extracting page 6101 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6101&page_size=25
# ✅ Found 25 cars on page 6101
# 📄 Total scraped: 2525
#
# 🔎 Extracting page 6102 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6102&page_size=25
# ✅ Found 25 cars on page 6102
# 📄 Total scraped: 2550
#
# 🔎 Extracting page 6103 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6103&page_size=25
# ✅ Found 25 cars on page 6103
# 📄 Total scraped: 2575
#
# 🔎 Extracting page 6104 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6104&page_size=25
# ✅ Found 25 cars on page 6104
# 📄 Total scraped: 2600
#
# 🔎 Extracting page 6105 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6105&page_size=25
# ✅ Found 25 cars on page 6105
# 📄 Total scraped: 2625
#
# 🔎 Extracting page 6106 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6106&page_size=25
# ✅ Found 25 cars on page 6106
# 📄 Total scraped: 2650
#
# 🔎 Extracting page 6107 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6107&page_size=25
# ✅ Found 25 cars on page 6107
# 📄 Total scraped: 2675
#
# 🔎 Extracting page 6108 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6108&page_size=25
# ✅ Found 25 cars on page 6108
# 📄 Total scraped: 2700
#
# 🔎 Extracting page 6109 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6109&page_size=25
# ✅ Found 25 cars on page 6109
# 📄 Total scraped: 2725
#
# 🔎 Extracting page 6110 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6110&page_size=25
# ✅ Found 25 cars on page 6110
# 📄 Total scraped: 2750
#
# 🔎 Extracting page 6111 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6111&page_size=25
# ✅ Found 25 cars on page 6111
# 📄 Total scraped: 2775
#
# 🔎 Extracting page 6112 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6112&page_size=25
# ✅ Found 25 cars on page 6112
# 📄 Total scraped: 2800
#
# 🔎 Extracting page 6113 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6113&page_size=25
# ✅ Found 25 cars on page 6113
# 📄 Total scraped: 2825
#
# 🔎 Extracting page 6114 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6114&page_size=25
# ✅ Found 25 cars on page 6114
# 📄 Total scraped: 2850
#
# 🔎 Extracting page 6115 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6115&page_size=25
# ✅ Found 25 cars on page 6115
# 📄 Total scraped: 2875
#
# 🔎 Extracting page 6116 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6116&page_size=25
# ✅ Found 25 cars on page 6116
# 📄 Total scraped: 2900
#
# 🔎 Extracting page 6117 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6117&page_size=25
# ✅ Found 25 cars on page 6117
# 📄 Total scraped: 2925
#
# 🔎 Extracting page 6118 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6118&page_size=25
# ✅ Found 25 cars on page 6118
# 📄 Total scraped: 2950
#
# 🔎 Extracting page 6119 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6119&page_size=25
# ✅ Found 25 cars on page 6119
# 📄 Total scraped: 2975
#
# 🔎 Extracting page 6120 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6120&page_size=25
# ✅ Found 25 cars on page 6120
# 📄 Total scraped: 3000
#
# 🔎 Extracting page 6121 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6121&page_size=25
# ✅ Found 25 cars on page 6121
# 📄 Total scraped: 3025
#
# 🔎 Extracting page 6122 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6122&page_size=25
# ✅ Found 25 cars on page 6122
# 📄 Total scraped: 3050
#
# 🔎 Extracting page 6123 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6123&page_size=25
# ✅ Found 25 cars on page 6123
# 📄 Total scraped: 3075
#
# 🔎 Extracting page 6124 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6124&page_size=25
# ✅ Found 25 cars on page 6124
# 📄 Total scraped: 3100
#
# 🔎 Extracting page 6125 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6125&page_size=25
# ✅ Found 25 cars on page 6125
# 📄 Total scraped: 3125
#
# 🔎 Extracting page 6126 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6126&page_size=25
# ✅ Found 25 cars on page 6126
# 📄 Total scraped: 3150
#
# 🔎 Extracting page 6127 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6127&page_size=25
# ✅ Found 25 cars on page 6127
# 📄 Total scraped: 3175
#
# 🔎 Extracting page 6128 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6128&page_size=25
# ✅ Found 25 cars on page 6128
# 📄 Total scraped: 3200
#
# 🔎 Extracting page 6129 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6129&page_size=25
# ✅ Found 25 cars on page 6129
# 📄 Total scraped: 3225
#
# 🔎 Extracting page 6130 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6130&page_size=25
# ✅ Found 25 cars on page 6130
# 📄 Total scraped: 3250
#
# 🔎 Extracting page 6131 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6131&page_size=25
# ✅ Found 25 cars on page 6131
# 📄 Total scraped: 3275
#
# 🔎 Extracting page 6132 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6132&page_size=25
# ✅ Found 25 cars on page 6132
# 📄 Total scraped: 3300
#
# 🔎 Extracting page 6133 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6133&page_size=25
# ✅ Found 25 cars on page 6133
# 📄 Total scraped: 3325
#
# 🔎 Extracting page 6134 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6134&page_size=25
# ✅ Found 25 cars on page 6134
# 📄 Total scraped: 3350
#
# 🔎 Extracting page 6135 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6135&page_size=25
# ✅ Found 25 cars on page 6135
# 📄 Total scraped: 3375
#
# 🔎 Extracting page 6136 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6136&page_size=25
# ✅ Found 25 cars on page 6136
# 📄 Total scraped: 3400
#
# 🔎 Extracting page 6137 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6137&page_size=25
# ✅ Found 25 cars on page 6137
# 📄 Total scraped: 3425
#
# 🔎 Extracting page 6138 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6138&page_size=25
# ✅ Found 25 cars on page 6138
# 📄 Total scraped: 3450
#
# 🔎 Extracting page 6139 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6139&page_size=25
# ✅ Found 25 cars on page 6139
# 📄 Total scraped: 3475
#
# 🔎 Extracting page 6140 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6140&page_size=25
# ✅ Found 25 cars on page 6140
# 📄 Total scraped: 3500
#
# 🔎 Extracting page 6141 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6141&page_size=25
# ✅ Found 25 cars on page 6141
# 📄 Total scraped: 3525
#
# 🔎 Extracting page 6142 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6142&page_size=25
# ✅ Found 25 cars on page 6142
# 📄 Total scraped: 3550
#
# 🔎 Extracting page 6143 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6143&page_size=25
# ✅ Found 25 cars on page 6143
# 📄 Total scraped: 3575
#
# 🔎 Extracting page 6144 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6144&page_size=25
# ✅ Found 25 cars on page 6144
# 📄 Total scraped: 3600
#
# 🔎 Extracting page 6145 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6145&page_size=25
# ✅ Found 25 cars on page 6145
# 📄 Total scraped: 3625
#
# 🔎 Extracting page 6146 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6146&page_size=25
# ✅ Found 25 cars on page 6146
# 📄 Total scraped: 3650
#
# 🔎 Extracting page 6147 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6147&page_size=25
# ✅ Found 25 cars on page 6147
# 📄 Total scraped: 3675
#
# 🔎 Extracting page 6148 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6148&page_size=25
# ✅ Found 25 cars on page 6148
# 📄 Total scraped: 3700
#
# 🔎 Extracting page 6149 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6149&page_size=25
# ✅ Found 25 cars on page 6149
# 📄 Total scraped: 3725
#
# 🔎 Extracting page 6150 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6150&page_size=25
# ✅ Found 25 cars on page 6150
# 📄 Total scraped: 3750
#
# 🔎 Extracting page 6151 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6151&page_size=25
# ✅ Found 25 cars on page 6151
# 📄 Total scraped: 3775
#
# 🔎 Extracting page 6152 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6152&page_size=25
# ✅ Found 25 cars on page 6152
# 📄 Total scraped: 3800
#
# 🔎 Extracting page 6153 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6153&page_size=25
# ✅ Found 25 cars on page 6153
# 📄 Total scraped: 3825
#
# 🔎 Extracting page 6154 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6154&page_size=25
# ✅ Found 25 cars on page 6154
# 📄 Total scraped: 3850
#
# 🔎 Extracting page 6155 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6155&page_size=25
# ✅ Found 25 cars on page 6155
# 📄 Total scraped: 3875
#
# 🔎 Extracting page 6156 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6156&page_size=25
# ✅ Found 25 cars on page 6156
# 📄 Total scraped: 3900
#
# 🔎 Extracting page 6157 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6157&page_size=25
# ✅ Found 25 cars on page 6157
# 📄 Total scraped: 3925
#
# 🔎 Extracting page 6158 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6158&page_size=25
# ✅ Found 25 cars on page 6158
# 📄 Total scraped: 3950
#
# 🔎 Extracting page 6159 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6159&page_size=25
# ✅ Found 25 cars on page 6159
# 📄 Total scraped: 3975
#
# 🔎 Extracting page 6160 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6160&page_size=25
# ✅ Found 25 cars on page 6160
# 📄 Total scraped: 4000
#
# 🔎 Extracting page 6161 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6161&page_size=25
# ✅ Found 25 cars on page 6161
# 📄 Total scraped: 4025
#
# 🔎 Extracting page 6162 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6162&page_size=25
# ✅ Found 25 cars on page 6162
# 📄 Total scraped: 4050
#
# 🔎 Extracting page 6163 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6163&page_size=25
# ✅ Found 25 cars on page 6163
# 📄 Total scraped: 4075
#
# 🔎 Extracting page 6164 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6164&page_size=25
# ✅ Found 25 cars on page 6164
# 📄 Total scraped: 4100
#
# 🔎 Extracting page 6165 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6165&page_size=25
# ✅ Found 25 cars on page 6165
# 📄 Total scraped: 4125
#
# 🔎 Extracting page 6166 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6166&page_size=25
# ✅ Found 25 cars on page 6166
# 📄 Total scraped: 4150
#
# 🔎 Extracting page 6167 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6167&page_size=25
# ✅ Found 25 cars on page 6167
# 📄 Total scraped: 4175
#
# 🔎 Extracting page 6168 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6168&page_size=25
# ✅ Found 25 cars on page 6168
# 📄 Total scraped: 4200
#
# 🔎 Extracting page 6169 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6169&page_size=25
# ✅ Found 25 cars on page 6169
# 📄 Total scraped: 4225
#
# 🔎 Extracting page 6170 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6170&page_size=25
# ✅ Found 25 cars on page 6170
# 📄 Total scraped: 4250
#
# 🔎 Extracting page 6171 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6171&page_size=25
# ✅ Found 25 cars on page 6171
# 📄 Total scraped: 4275
#
# 🔎 Extracting page 6172 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6172&page_size=25
# ✅ Found 25 cars on page 6172
# 📄 Total scraped: 4300
#
# 🔎 Extracting page 6173 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6173&page_size=25
# ✅ Found 25 cars on page 6173
# 📄 Total scraped: 4325
#
# 🔎 Extracting page 6174 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6174&page_size=25
# ✅ Found 25 cars on page 6174
# 📄 Total scraped: 4350
#
# 🔎 Extracting page 6175 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6175&page_size=25
# ✅ Found 25 cars on page 6175
# 📄 Total scraped: 4375
#
# 🔎 Extracting page 6176 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6176&page_size=25
# ✅ Found 25 cars on page 6176
# 📄 Total scraped: 4400
#
# 🔎 Extracting page 6177 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6177&page_size=25
# ✅ Found 25 cars on page 6177
# 📄 Total scraped: 4425
#
# 🔎 Extracting page 6178 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6178&page_size=25
# ✅ Found 25 cars on page 6178
# 📄 Total scraped: 4450
#
# 🔎 Extracting page 6179 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6179&page_size=25
# ✅ Found 25 cars on page 6179
# 📄 Total scraped: 4475
#
# 🔎 Extracting page 6180 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6180&page_size=25
# ✅ Found 25 cars on page 6180
# 📄 Total scraped: 4500
#
# 🔎 Extracting page 6181 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6181&page_size=25
# ✅ Found 25 cars on page 6181
# 📄 Total scraped: 4525
#
# 🔎 Extracting page 6182 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6182&page_size=25
# ✅ Found 25 cars on page 6182
# 📄 Total scraped: 4550
#
# 🔎 Extracting page 6183 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6183&page_size=25
# ✅ Found 25 cars on page 6183
# 📄 Total scraped: 4575
#
# 🔎 Extracting page 6184 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6184&page_size=25
# ✅ Found 25 cars on page 6184
# 📄 Total scraped: 4600
#
# 🔎 Extracting page 6185 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6185&page_size=25
# ✅ Found 25 cars on page 6185
# 📄 Total scraped: 4625
#
# 🔎 Extracting page 6186 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6186&page_size=25
# ✅ Found 25 cars on page 6186
# 📄 Total scraped: 4650
#
# 🔎 Extracting page 6187 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6187&page_size=25
# ✅ Found 25 cars on page 6187
# 📄 Total scraped: 4675
#
# 🔎 Extracting page 6188 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6188&page_size=25
# ✅ Found 25 cars on page 6188
# 📄 Total scraped: 4700
#
# 🔎 Extracting page 6189 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6189&page_size=25
# ✅ Found 25 cars on page 6189
# 📄 Total scraped: 4725
#
# 🔎 Extracting page 6190 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6190&page_size=25
# ✅ Found 25 cars on page 6190
# 📄 Total scraped: 4750
#
# 🔎 Extracting page 6191 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6191&page_size=25
# ✅ Found 25 cars on page 6191
# 📄 Total scraped: 4775
#
# 🔎 Extracting page 6192 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6192&page_size=25
# ✅ Found 25 cars on page 6192
# 📄 Total scraped: 4800
#
# 🔎 Extracting page 6193 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6193&page_size=25
# ✅ Found 25 cars on page 6193
# 📄 Total scraped: 4825
#
# 🔎 Extracting page 6194 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6194&page_size=25
# ✅ Found 25 cars on page 6194
# 📄 Total scraped: 4850
#
# 🔎 Extracting page 6195 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6195&page_size=25
# ✅ Found 25 cars on page 6195
# 📄 Total scraped: 4875
#
# 🔎 Extracting page 6196 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6196&page_size=25
# ✅ Found 25 cars on page 6196
# 📄 Total scraped: 4900
#
# 🔎 Extracting page 6197 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6197&page_size=25
# ✅ Found 25 cars on page 6197
# 📄 Total scraped: 4925
#
# 🔎 Extracting page 6198 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6198&page_size=25
# ✅ Found 25 cars on page 6198
# 📄 Total scraped: 4950
#
# 🔎 Extracting page 6199 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6199&page_size=25
# ✅ Found 25 cars on page 6199
# 📄 Total scraped: 4975
#
# 🔎 Extracting page 6200 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6200&page_size=25
# ✅ Found 25 cars on page 6200
# 📄 Total scraped: 5000
#
# 🔎 Extracting page 6201 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6201&page_size=25
# ✅ Found 25 cars on page 6201
# 📄 Total scraped: 5025
#
# 🔎 Extracting page 6202 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6202&page_size=25
# ✅ Found 25 cars on page 6202
# 📄 Total scraped: 5050
#
# 🔎 Extracting page 6203 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6203&page_size=25
# ✅ Found 25 cars on page 6203
# 📄 Total scraped: 5075
#
# 🔎 Extracting page 6204 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6204&page_size=25
# ✅ Found 25 cars on page 6204
# 📄 Total scraped: 5100
#
# 🔎 Extracting page 6205 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6205&page_size=25
# ✅ Found 25 cars on page 6205
# 📄 Total scraped: 5125
#
# 🔎 Extracting page 6206 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6206&page_size=25
# ✅ Found 25 cars on page 6206
# 📄 Total scraped: 5150
#
# 🔎 Extracting page 6207 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6207&page_size=25
# ✅ Found 25 cars on page 6207
# 📄 Total scraped: 5175
#
# 🔎 Extracting page 6208 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6208&page_size=25
# ✅ Found 25 cars on page 6208
# 📄 Total scraped: 5200
#
# 🔎 Extracting page 6209 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6209&page_size=25
# ✅ Found 25 cars on page 6209
# 📄 Total scraped: 5225
#
# 🔎 Extracting page 6210 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6210&page_size=25
# ✅ Found 25 cars on page 6210
# 📄 Total scraped: 5250
#
# 🔎 Extracting page 6211 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6211&page_size=25
# ✅ Found 25 cars on page 6211
# 📄 Total scraped: 5275
#
# 🔎 Extracting page 6212 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6212&page_size=25
# ✅ Found 25 cars on page 6212
# 📄 Total scraped: 5300
#
# 🔎 Extracting page 6213 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6213&page_size=25
# ✅ Found 25 cars on page 6213
# 📄 Total scraped: 5325
#
# 🔎 Extracting page 6214 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6214&page_size=25
# ✅ Found 25 cars on page 6214
# 📄 Total scraped: 5350
#
# 🔎 Extracting page 6215 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6215&page_size=25
# ✅ Found 25 cars on page 6215
# 📄 Total scraped: 5375
#
# 🔎 Extracting page 6216 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6216&page_size=25
# ✅ Found 25 cars on page 6216
# 📄 Total scraped: 5400
#
# 🔎 Extracting page 6217 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6217&page_size=25
# ✅ Found 25 cars on page 6217
# 📄 Total scraped: 5425
#
# 🔎 Extracting page 6218 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6218&page_size=25
# ✅ Found 25 cars on page 6218
# 📄 Total scraped: 5450
#
# 🔎 Extracting page 6219 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6219&page_size=25
# ✅ Found 25 cars on page 6219
# 📄 Total scraped: 5475
#
# 🔎 Extracting page 6220 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6220&page_size=25
# ✅ Found 25 cars on page 6220
# 📄 Total scraped: 5500
#
# 🔎 Extracting page 6221 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6221&page_size=25
# ✅ Found 25 cars on page 6221
# 📄 Total scraped: 5525
#
# 🔎 Extracting page 6222 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6222&page_size=25
# ✅ Found 25 cars on page 6222
# 📄 Total scraped: 5550
#
# 🔎 Extracting page 6223 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6223&page_size=25
# ✅ Found 25 cars on page 6223
# 📄 Total scraped: 5575
#
# 🔎 Extracting page 6224 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6224&page_size=25
# ✅ Found 25 cars on page 6224
# 📄 Total scraped: 5600
#
# 🔎 Extracting page 6225 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6225&page_size=25
# ✅ Found 25 cars on page 6225
# 📄 Total scraped: 5625
#
# 🔎 Extracting page 6226 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6226&page_size=25
# ✅ Found 25 cars on page 6226
# 📄 Total scraped: 5650
#
# 🔎 Extracting page 6227 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6227&page_size=25
# ✅ Found 25 cars on page 6227
# 📄 Total scraped: 5675
#
# 🔎 Extracting page 6228 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6228&page_size=25
# ✅ Found 25 cars on page 6228
# 📄 Total scraped: 5700
#
# 🔎 Extracting page 6229 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6229&page_size=25
# ✅ Found 25 cars on page 6229
# 📄 Total scraped: 5725
#
# 🔎 Extracting page 6230 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6230&page_size=25
# ✅ Found 25 cars on page 6230
# 📄 Total scraped: 5750
#
# 🔎 Extracting page 6231 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6231&page_size=25
# ✅ Found 25 cars on page 6231
# 📄 Total scraped: 5775
#
# 🔎 Extracting page 6232 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6232&page_size=25
# ✅ Found 25 cars on page 6232
# 📄 Total scraped: 5800
#
# 🔎 Extracting page 6233 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6233&page_size=25
# ✅ Found 25 cars on page 6233
# 📄 Total scraped: 5825
#
# 🔎 Extracting page 6234 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6234&page_size=25
# ✅ Found 25 cars on page 6234
# 📄 Total scraped: 5850
#
# 🔎 Extracting page 6235 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6235&page_size=25
# ✅ Found 25 cars on page 6235
# 📄 Total scraped: 5875
#
# 🔎 Extracting page 6236 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6236&page_size=25
# ✅ Found 25 cars on page 6236
# 📄 Total scraped: 5900
#
# 🔎 Extracting page 6237 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6237&page_size=25
# ✅ Found 25 cars on page 6237
# 📄 Total scraped: 5925
#
# 🔎 Extracting page 6238 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6238&page_size=25
# ✅ Found 25 cars on page 6238
# 📄 Total scraped: 5950
#
# 🔎 Extracting page 6239 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6239&page_size=25
# ✅ Found 25 cars on page 6239
# 📄 Total scraped: 5975
#
# 🔎 Extracting page 6240 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6240&page_size=25
# ✅ Found 25 cars on page 6240
# 📄 Total scraped: 6000
#
# 🔎 Extracting page 6241 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6241&page_size=25
# ✅ Found 25 cars on page 6241
# 📄 Total scraped: 6025
#
# 🔎 Extracting page 6242 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6242&page_size=25
# ✅ Found 25 cars on page 6242
# 📄 Total scraped: 6050
#
# 🔎 Extracting page 6243 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6243&page_size=25
# ✅ Found 25 cars on page 6243
# 📄 Total scraped: 6075
#
# 🔎 Extracting page 6244 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6244&page_size=25
# ✅ Found 25 cars on page 6244
# 📄 Total scraped: 6100
#
# 🔎 Extracting page 6245 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6245&page_size=25
# ✅ Found 25 cars on page 6245
# 📄 Total scraped: 6125
#
# 🔎 Extracting page 6246 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6246&page_size=25
# ✅ Found 25 cars on page 6246
# 📄 Total scraped: 6150
#
# 🔎 Extracting page 6247 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6247&page_size=25
# ✅ Found 25 cars on page 6247
# 📄 Total scraped: 6175
#
# 🔎 Extracting page 6248 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6248&page_size=25
# ✅ Found 25 cars on page 6248
# 📄 Total scraped: 6200
#
# 🔎 Extracting page 6249 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6249&page_size=25
# ✅ Found 25 cars on page 6249
# 📄 Total scraped: 6225
#
# 🔎 Extracting page 6250 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6250&page_size=25
# ✅ Found 25 cars on page 6250
# 📄 Total scraped: 6250
#
# 🔎 Extracting page 6251 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6251&page_size=25
# ✅ Found 25 cars on page 6251
# 📄 Total scraped: 6275
#
# 🔎 Extracting page 6252 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6252&page_size=25
# ✅ Found 25 cars on page 6252
# 📄 Total scraped: 6300
#
# 🔎 Extracting page 6253 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6253&page_size=25
# ✅ Found 25 cars on page 6253
# 📄 Total scraped: 6325
#
# 🔎 Extracting page 6254 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6254&page_size=25
# ✅ Found 25 cars on page 6254
# 📄 Total scraped: 6350
#
# 🔎 Extracting page 6255 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6255&page_size=25
# ✅ Found 25 cars on page 6255
# 📄 Total scraped: 6375
#
# 🔎 Extracting page 6256 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6256&page_size=25
# ✅ Found 25 cars on page 6256
# 📄 Total scraped: 6400
#
# 🔎 Extracting page 6257 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6257&page_size=25
# ✅ Found 25 cars on page 6257
# 📄 Total scraped: 6425
#
# 🔎 Extracting page 6258 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6258&page_size=25
# ✅ Found 25 cars on page 6258
# 📄 Total scraped: 6450
#
# 🔎 Extracting page 6259 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6259&page_size=25
# ✅ Found 25 cars on page 6259
# 📄 Total scraped: 6475
#
# 🔎 Extracting page 6260 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6260&page_size=25
# ✅ Found 25 cars on page 6260
# 📄 Total scraped: 6500
#
# 🔎 Extracting page 6261 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6261&page_size=25
# ✅ Found 25 cars on page 6261
# 📄 Total scraped: 6525
#
# 🔎 Extracting page 6262 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6262&page_size=25
# ✅ Found 25 cars on page 6262
# 📄 Total scraped: 6550
#
# 🔎 Extracting page 6263 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6263&page_size=25
# ✅ Found 25 cars on page 6263
# 📄 Total scraped: 6575
#
# 🔎 Extracting page 6264 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6264&page_size=25
# ✅ Found 25 cars on page 6264
# 📄 Total scraped: 6600
#
# 🔎 Extracting page 6265 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6265&page_size=25
# ✅ Found 25 cars on page 6265
# 📄 Total scraped: 6625
#
# 🔎 Extracting page 6266 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6266&page_size=25
# ✅ Found 25 cars on page 6266
# 📄 Total scraped: 6650
#
# 🔎 Extracting page 6267 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6267&page_size=25
# ✅ Found 25 cars on page 6267
# 📄 Total scraped: 6675
#
# 🔎 Extracting page 6268 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6268&page_size=25
# ✅ Found 25 cars on page 6268
# 📄 Total scraped: 6700
#
# 🔎 Extracting page 6269 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6269&page_size=25
# ✅ Found 25 cars on page 6269
# 📄 Total scraped: 6725
#
# 🔎 Extracting page 6270 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6270&page_size=25
# ✅ Found 25 cars on page 6270
# 📄 Total scraped: 6750
#
# 🔎 Extracting page 6271 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6271&page_size=25
# ✅ Found 25 cars on page 6271
# 📄 Total scraped: 6775
#
# 🔎 Extracting page 6272 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6272&page_size=25
# ✅ Found 25 cars on page 6272
# 📄 Total scraped: 6800
#
# 🔎 Extracting page 6273 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6273&page_size=25
# ✅ Found 25 cars on page 6273
# 📄 Total scraped: 6825
#
# 🔎 Extracting page 6274 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6274&page_size=25
# ✅ Found 25 cars on page 6274
# 📄 Total scraped: 6850
#
# 🔎 Extracting page 6275 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6275&page_size=25
# ✅ Found 25 cars on page 6275
# 📄 Total scraped: 6875
#
# 🔎 Extracting page 6276 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6276&page_size=25
# ✅ Found 25 cars on page 6276
# 📄 Total scraped: 6900
#
# 🔎 Extracting page 6277 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6277&page_size=25
# ✅ Found 25 cars on page 6277
# 📄 Total scraped: 6925
#
# 🔎 Extracting page 6278 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6278&page_size=25
# ✅ Found 25 cars on page 6278
# 📄 Total scraped: 6950
#
# 🔎 Extracting page 6279 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6279&page_size=25
# ✅ Found 25 cars on page 6279
# 📄 Total scraped: 6975
#
# 🔎 Extracting page 6280 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6280&page_size=25
# ✅ Found 25 cars on page 6280
# 📄 Total scraped: 7000
#
# 🔎 Extracting page 6281 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6281&page_size=25
# ✅ Found 25 cars on page 6281
# 📄 Total scraped: 7025
#
# 🔎 Extracting page 6282 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6282&page_size=25
# ✅ Found 25 cars on page 6282
# 📄 Total scraped: 7050
#
# 🔎 Extracting page 6283 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6283&page_size=25
# ✅ Found 25 cars on page 6283
# 📄 Total scraped: 7075
#
# 🔎 Extracting page 6284 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6284&page_size=25
# ✅ Found 25 cars on page 6284
# 📄 Total scraped: 7100
#
# 🔎 Extracting page 6285 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6285&page_size=25
# ✅ Found 25 cars on page 6285
# 📄 Total scraped: 7125
#
# 🔎 Extracting page 6286 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6286&page_size=25
# ✅ Found 25 cars on page 6286
# 📄 Total scraped: 7150
#
# 🔎 Extracting page 6287 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6287&page_size=25
# ✅ Found 25 cars on page 6287
# 📄 Total scraped: 7175
#
# 🔎 Extracting page 6288 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6288&page_size=25
# ✅ Found 25 cars on page 6288
# 📄 Total scraped: 7200
#
# 🔎 Extracting page 6289 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6289&page_size=25
# ✅ Found 25 cars on page 6289
# 📄 Total scraped: 7225
#
# 🔎 Extracting page 6290 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6290&page_size=25
# ✅ Found 25 cars on page 6290
# 📄 Total scraped: 7250
#
# 🔎 Extracting page 6291 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6291&page_size=25
# ✅ Found 25 cars on page 6291
# 📄 Total scraped: 7275
#
# 🔎 Extracting page 6292 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6292&page_size=25
# ✅ Found 25 cars on page 6292
# 📄 Total scraped: 7300
#
# 🔎 Extracting page 6293 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6293&page_size=25
# ✅ Found 25 cars on page 6293
# 📄 Total scraped: 7325
#
# 🔎 Extracting page 6294 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6294&page_size=25
# ✅ Found 25 cars on page 6294
# 📄 Total scraped: 7350
#
# 🔎 Extracting page 6295 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6295&page_size=25
# ✅ Found 25 cars on page 6295
# 📄 Total scraped: 7375
#
# 🔎 Extracting page 6296 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6296&page_size=25
# ✅ Found 25 cars on page 6296
# 📄 Total scraped: 7400
#
# 🔎 Extracting page 6297 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6297&page_size=25
# ✅ Found 25 cars on page 6297
# 📄 Total scraped: 7425
#
# 🔎 Extracting page 6298 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6298&page_size=25
# ✅ Found 25 cars on page 6298
# 📄 Total scraped: 7450
#
# 🔎 Extracting page 6299 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6299&page_size=25
# ✅ Found 25 cars on page 6299
# 📄 Total scraped: 7475
#
# 🔎 Extracting page 6300 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6300&page_size=25
# ✅ Found 25 cars on page 6300
# 📄 Total scraped: 7500
#
# 🔎 Extracting page 6301 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6301&page_size=25
# ✅ Found 25 cars on page 6301
# 📄 Total scraped: 7525
#
# 🔎 Extracting page 6302 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6302&page_size=25
# ✅ Found 25 cars on page 6302
# 📄 Total scraped: 7550
#
# 🔎 Extracting page 6303 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6303&page_size=25
# ✅ Found 25 cars on page 6303
# 📄 Total scraped: 7575
#
# 🔎 Extracting page 6304 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6304&page_size=25
# ✅ Found 25 cars on page 6304
# 📄 Total scraped: 7600
#
# 🔎 Extracting page 6305 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6305&page_size=25
# ✅ Found 25 cars on page 6305
# 📄 Total scraped: 7625
#
# 🔎 Extracting page 6306 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6306&page_size=25
# ✅ Found 25 cars on page 6306
# 📄 Total scraped: 7650
#
# 🔎 Extracting page 6307 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6307&page_size=25
# ✅ Found 25 cars on page 6307
# 📄 Total scraped: 7675
#
# 🔎 Extracting page 6308 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6308&page_size=25
# ✅ Found 25 cars on page 6308
# 📄 Total scraped: 7700
#
# 🔎 Extracting page 6309 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6309&page_size=25
# ✅ Found 25 cars on page 6309
# 📄 Total scraped: 7725
#
# 🔎 Extracting page 6310 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6310&page_size=25
# ✅ Found 25 cars on page 6310
# 📄 Total scraped: 7750
#
# 🔎 Extracting page 6311 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6311&page_size=25
# ✅ Found 25 cars on page 6311
# 📄 Total scraped: 7775
#
# 🔎 Extracting page 6312 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6312&page_size=25
# ✅ Found 25 cars on page 6312
# 📄 Total scraped: 7800
#
# 🔎 Extracting page 6313 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6313&page_size=25
# ✅ Found 25 cars on page 6313
# 📄 Total scraped: 7825
#
# 🔎 Extracting page 6314 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6314&page_size=25
# ✅ Found 25 cars on page 6314
# 📄 Total scraped: 7850
#
# ...
# ✅ Found 25 cars on page 6874
# 📄 Total scraped: 21850
#
# 🔎 Extracting page 6875 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6875&page_size=25
# ✅ Found 25 cars on page 6875
# 📄 Total scraped: 21875
#
# 🔎 Extracting page 6876 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6876&page_size=25
# ✅ Found 25 cars on page 6876
# 📄 Total scraped: 21900
#
# 🔎 Extracting page 6877 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6877&page_size=25
# ✅ Found 25 cars on page 6877
# 📄 Total scraped: 21925
#
# 🔎 Extracting page 6878 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6878&page_size=25
# ✅ Found 25 cars on page 6878
# 📄 Total scraped: 21950
#
# 🔎 Extracting page 6879 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6879&page_size=25
# ✅ Found 25 cars on page 6879
# 📄 Total scraped: 21975
#
# 🔎 Extracting page 6880 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6880&page_size=25
# ✅ Found 25 cars on page 6880
# 📄 Total scraped: 22000
#
# 🔎 Extracting page 6881 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6881&page_size=25
# ✅ Found 25 cars on page 6881
# 📄 Total scraped: 22025
#
# 🔎 Extracting page 6882 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6882&page_size=25
# ✅ Found 25 cars on page 6882
# 📄 Total scraped: 22050
#
# 🔎 Extracting page 6883 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6883&page_size=25
# ✅ Found 25 cars on page 6883
# 📄 Total scraped: 22075
#
# 🔎 Extracting page 6884 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6884&page_size=25
# ✅ Found 25 cars on page 6884
# 📄 Total scraped: 22100
#
# 🔎 Extracting page 6885 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6885&page_size=25
# ✅ Found 25 cars on page 6885
# 📄 Total scraped: 22125
#
# 🔎 Extracting page 6886 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6886&page_size=25
# ✅ Found 25 cars on page 6886
# 📄 Total scraped: 22150
#
# 🔎 Extracting page 6887 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6887&page_size=25
# ✅ Found 25 cars on page 6887
# 📄 Total scraped: 22175
#
# 🔎 Extracting page 6888 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6888&page_size=25
# ✅ Found 25 cars on page 6888
# 📄 Total scraped: 22200
#
# 🔎 Extracting page 6889 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6889&page_size=25
# ✅ Found 25 cars on page 6889
# 📄 Total scraped: 22225
#
# 🔎 Extracting page 6890 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6890&page_size=25
# ✅ Found 25 cars on page 6890
# 📄 Total scraped: 22250
#
# 🔎 Extracting page 6891 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6891&page_size=25
# ✅ Found 25 cars on page 6891
# 📄 Total scraped: 22275
#
# 🔎 Extracting page 6892 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6892&page_size=25
# ✅ Found 25 cars on page 6892
# 📄 Total scraped: 22300
#
# 🔎 Extracting page 6893 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6893&page_size=25
# ✅ Found 25 cars on page 6893
# 📄 Total scraped: 22325
#
# 🔎 Extracting page 6894 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6894&page_size=25
# ✅ Found 25 cars on page 6894
# 📄 Total scraped: 22350
#
# 🔎 Extracting page 6895 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6895&page_size=25
# ✅ Found 25 cars on page 6895
# 📄 Total scraped: 22375
#
# 🔎 Extracting page 6896 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6896&page_size=25
# ✅ Found 25 cars on page 6896
# 📄 Total scraped: 22400
#
# 🔎 Extracting page 6897 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6897&page_size=25
# ✅ Found 25 cars on page 6897
# 📄 Total scraped: 22425
#
# 🔎 Extracting page 6898 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6898&page_size=25
# ✅ Found 25 cars on page 6898
# 📄 Total scraped: 22450
#
# 🔎 Extracting page 6899 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6899&page_size=25
# ✅ Found 25 cars on page 6899
# 📄 Total scraped: 22475
#
# 🔎 Extracting page 6900 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6900&page_size=25
# ✅ Found 25 cars on page 6900
# 📄 Total scraped: 22500
#
# 🔎 Extracting page 6901 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6901&page_size=25
# ✅ Found 25 cars on page 6901
# 📄 Total scraped: 22525
#
# 🔎 Extracting page 6902 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6902&page_size=25
# ✅ Found 25 cars on page 6902
# 📄 Total scraped: 22550
#
# 🔎 Extracting page 6903 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6903&page_size=25
# ✅ Found 25 cars on page 6903
# 📄 Total scraped: 22575
#
# 🔎 Extracting page 6904 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6904&page_size=25
# ✅ Found 25 cars on page 6904
# 📄 Total scraped: 22600
#
# 🔎 Extracting page 6905 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6905&page_size=25
# ✅ Found 25 cars on page 6905
# 📄 Total scraped: 22625
#
# 🔎 Extracting page 6906 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6906&page_size=25
# ✅ Found 25 cars on page 6906
# 📄 Total scraped: 22650
#
# 🔎 Extracting page 6907 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6907&page_size=25
# ✅ Found 25 cars on page 6907
# 📄 Total scraped: 22675
#
# 🔎 Extracting page 6908 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6908&page_size=25
# ✅ Found 25 cars on page 6908
# 📄 Total scraped: 22700
#
# 🔎 Extracting page 6909 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6909&page_size=25
# ✅ Found 25 cars on page 6909
# 📄 Total scraped: 22725
#
# 🔎 Extracting page 6910 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6910&page_size=25
# ✅ Found 25 cars on page 6910
# 📄 Total scraped: 22750
#
# 🔎 Extracting page 6911 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6911&page_size=25
# ✅ Found 25 cars on page 6911
# 📄 Total scraped: 22775
#
# 🔎 Extracting page 6912 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6912&page_size=25
# ✅ Found 25 cars on page 6912
# 📄 Total scraped: 22800
#
# 🔎 Extracting page 6913 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6913&page_size=25
# ✅ Found 25 cars on page 6913
# 📄 Total scraped: 22825
#
# 🔎 Extracting page 6914 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6914&page_size=25
# ✅ Found 25 cars on page 6914
# 📄 Total scraped: 22850
#
# 🔎 Extracting page 6915 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6915&page_size=25
# ✅ Found 25 cars on page 6915
# 📄 Total scraped: 22875
#
# 🔎 Extracting page 6916 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6916&page_size=25
# ✅ Found 25 cars on page 6916
# 📄 Total scraped: 22900
#
# 🔎 Extracting page 6917 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6917&page_size=25
# ✅ Found 25 cars on page 6917
# 📄 Total scraped: 22925
#
# 🔎 Extracting page 6918 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6918&page_size=25
# ✅ Found 25 cars on page 6918
# 📄 Total scraped: 22950
#
# 🔎 Extracting page 6919 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6919&page_size=25
# ✅ Found 25 cars on page 6919
# 📄 Total scraped: 22975
#
# 🔎 Extracting page 6920 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6920&page_size=25
# ✅ Found 25 cars on page 6920
# 📄 Total scraped: 23000
#
# 🔎 Extracting page 6921 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6921&page_size=25
# ✅ Found 25 cars on page 6921
# 📄 Total scraped: 23025
#
# 🔎 Extracting page 6922 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6922&page_size=25
# ✅ Found 25 cars on page 6922
# 📄 Total scraped: 23050
#
# 🔎 Extracting page 6923 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6923&page_size=25
# ✅ Found 25 cars on page 6923
# 📄 Total scraped: 23075
#
# 🔎 Extracting page 6924 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6924&page_size=25
# ✅ Found 25 cars on page 6924
# 📄 Total scraped: 23100
#
# 🔎 Extracting page 6925 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6925&page_size=25
# ✅ Found 25 cars on page 6925
# 📄 Total scraped: 23125
#
# 🔎 Extracting page 6926 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6926&page_size=25
# ✅ Found 25 cars on page 6926
# 📄 Total scraped: 23150
#
# 🔎 Extracting page 6927 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6927&page_size=25
# ✅ Found 25 cars on page 6927
# 📄 Total scraped: 23175
#
# 🔎 Extracting page 6928 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6928&page_size=25
# ✅ Found 25 cars on page 6928
# 📄 Total scraped: 23200
#
# 🔎 Extracting page 6929 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6929&page_size=25
# ✅ Found 25 cars on page 6929
# 📄 Total scraped: 23225
#
# 🔎 Extracting page 6930 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6930&page_size=25
# ✅ Found 25 cars on page 6930
# 📄 Total scraped: 23250
#
# 🔎 Extracting page 6931 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6931&page_size=25
# ✅ Found 25 cars on page 6931
# 📄 Total scraped: 23275
#
# 🔎 Extracting page 6932 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6932&page_size=25
# ✅ Found 25 cars on page 6932
# 📄 Total scraped: 23300
#
# 🔎 Extracting page 6933 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6933&page_size=25
# ✅ Found 25 cars on page 6933
# 📄 Total scraped: 23325
#
# 🔎 Extracting page 6934 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6934&page_size=25
# ✅ Found 25 cars on page 6934
# 📄 Total scraped: 23350
#
# 🔎 Extracting page 6935 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6935&page_size=25
# ✅ Found 25 cars on page 6935
# 📄 Total scraped: 23375
#
# 🔎 Extracting page 6936 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6936&page_size=25
# ✅ Found 25 cars on page 6936
# 📄 Total scraped: 23400
#
# 🔎 Extracting page 6937 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6937&page_size=25
# ✅ Found 25 cars on page 6937
# 📄 Total scraped: 23425
#
# 🔎 Extracting page 6938 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6938&page_size=25
# ✅ Found 25 cars on page 6938
# 📄 Total scraped: 23450
#
# 🔎 Extracting page 6939 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6939&page_size=25
# ✅ Found 25 cars on page 6939
# 📄 Total scraped: 23475
#
# 🔎 Extracting page 6940 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6940&page_size=25
# ✅ Found 25 cars on page 6940
# 📄 Total scraped: 23500
#
# 🔎 Extracting page 6941 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6941&page_size=25
# ✅ Found 25 cars on page 6941
# 📄 Total scraped: 23525
#
# 🔎 Extracting page 6942 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6942&page_size=25
# ✅ Found 25 cars on page 6942
# 📄 Total scraped: 23550
#
# 🔎 Extracting page 6943 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6943&page_size=25
# ✅ Found 25 cars on page 6943
# 📄 Total scraped: 23575
#
# 🔎 Extracting page 6944 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6944&page_size=25
# ✅ Found 25 cars on page 6944
# 📄 Total scraped: 23600
#
# 🔎 Extracting page 6945 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6945&page_size=25
# ✅ Found 25 cars on page 6945
# 📄 Total scraped: 23625
#
# 🔎 Extracting page 6946 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6946&page_size=25
# ✅ Found 25 cars on page 6946
# 📄 Total scraped: 23650
#
# 🔎 Extracting page 6947 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6947&page_size=25
# ✅ Found 25 cars on page 6947
# 📄 Total scraped: 23675
#
# 🔎 Extracting page 6948 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6948&page_size=25
# ✅ Found 25 cars on page 6948
# 📄 Total scraped: 23700
#
# 🔎 Extracting page 6949 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6949&page_size=25
# ✅ Found 25 cars on page 6949
# 📄 Total scraped: 23725
#
# 🔎 Extracting page 6950 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6950&page_size=25
# ✅ Found 25 cars on page 6950
# 📄 Total scraped: 23750
#
# 🔎 Extracting page 6951 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6951&page_size=25
# ✅ Found 25 cars on page 6951
# 📄 Total scraped: 23775
#
# 🔎 Extracting page 6952 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6952&page_size=25
# ✅ Found 25 cars on page 6952
# 📄 Total scraped: 23800
#
# 🔎 Extracting page 6953 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6953&page_size=25
# ✅ Found 25 cars on page 6953
# 📄 Total scraped: 23825
#
# 🔎 Extracting page 6954 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6954&page_size=25
# ✅ Found 25 cars on page 6954
# 📄 Total scraped: 23850
#
# 🔎 Extracting page 6955 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6955&page_size=25
# ✅ Found 25 cars on page 6955
# 📄 Total scraped: 23875
#
# 🔎 Extracting page 6956 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6956&page_size=25
# ✅ Found 25 cars on page 6956
# 📄 Total scraped: 23900
#
# 🔎 Extracting page 6957 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6957&page_size=25
# ✅ Found 25 cars on page 6957
# 📄 Total scraped: 23925
#
# 🔎 Extracting page 6958 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6958&page_size=25
# ✅ Found 25 cars on page 6958
# 📄 Total scraped: 23950
#
# 🔎 Extracting page 6959 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6959&page_size=25
# ✅ Found 25 cars on page 6959
# 📄 Total scraped: 23975
#
# 🔎 Extracting page 6960 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6960&page_size=25
# ✅ Found 25 cars on page 6960
# 📄 Total scraped: 24000
#
# 🔎 Extracting page 6961 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6961&page_size=25
# ✅ Found 25 cars on page 6961
# 📄 Total scraped: 24025
#
# 🔎 Extracting page 6962 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6962&page_size=25
# ✅ Found 25 cars on page 6962
# 📄 Total scraped: 24050
#
# 🔎 Extracting page 6963 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6963&page_size=25
# ✅ Found 25 cars on page 6963
# 📄 Total scraped: 24075
#
# 🔎 Extracting page 6964 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6964&page_size=25
# ✅ Found 25 cars on page 6964
# 📄 Total scraped: 24100
#
# 🔎 Extracting page 6965 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6965&page_size=25
# ✅ Found 25 cars on page 6965
# 📄 Total scraped: 24125
#
# 🔎 Extracting page 6966 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6966&page_size=25
# ✅ Found 25 cars on page 6966
# 📄 Total scraped: 24150
#
# 🔎 Extracting page 6967 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6967&page_size=25
# ✅ Found 25 cars on page 6967
# 📄 Total scraped: 24175
#
# 🔎 Extracting page 6968 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6968&page_size=25
# ✅ Found 25 cars on page 6968
# 📄 Total scraped: 24200
#
# 🔎 Extracting page 6969 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6969&page_size=25
# ✅ Found 25 cars on page 6969
# 📄 Total scraped: 24225
#
# 🔎 Extracting page 6970 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6970&page_size=25
# ✅ Found 25 cars on page 6970
# 📄 Total scraped: 24250
#
# 🔎 Extracting page 6971 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6971&page_size=25
# ✅ Found 25 cars on page 6971
# 📄 Total scraped: 24275
#
# 🔎 Extracting page 6972 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6972&page_size=25
# ✅ Found 25 cars on page 6972
# 📄 Total scraped: 24300
#
# 🔎 Extracting page 6973 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6973&page_size=25
# ✅ Found 25 cars on page 6973
# 📄 Total scraped: 24325
#
# 🔎 Extracting page 6974 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6974&page_size=25
# ✅ Found 25 cars on page 6974
# 📄 Total scraped: 24350
#
# 🔎 Extracting page 6975 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6975&page_size=25
# ✅ Found 25 cars on page 6975
# 📄 Total scraped: 24375
#
# 🔎 Extracting page 6976 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6976&page_size=25
# ✅ Found 25 cars on page 6976
# 📄 Total scraped: 24400
#
# 🔎 Extracting page 6977 - https://www.carlist.my/cars-for-sale/malaysia?page_number=6977&page_size=25
# ✅ Found 25 cars on page 6977
# 📄 Total scraped: 24425

# %% [markdown]
# # 6. Saving Data to CSV
# The script checks if any car listings were successfully scraped.
#
# It opens the output CSV file for writing and uses csv.DictWriter to write the data.
#
# The writeheader() method writes the column headers, while writerows() writes the data for all the car listings.

# %%
# Save the extracted data to a CSV file
if car_listings:
    with open(output_file, 'w', newline='', encoding='utf-8') as f:
        writer = csv.DictWriter(f, fieldnames=car_listings[0].keys())
        writer.writeheader()  # Write the column headers
        writer.writerows(car_listings)  # Write the car listings data
    print(f"\n✅ Saved {len(car_listings)} cars to '{output_file}'")
else:
    print("\n⚠️ No car listings found.")
# Out:
# ✅ Saved 24425 cars to 'D:/camily_carlist_listings_2.csv'

# %% [markdown]
# # 7. Calculate Total Execution Time
# At the end of the script, after all scraping activities and file-saving operations, the following code is added to record the end time and calculate the total execution time:

# %%
# End time and elapsed time calculation
end_time = time.time()
execution_time = end_time - start_time
print(f"\n🕒 Total execution time: {execution_time:.2f} seconds")
# Out:
# 🕒 Total execution time: 3719.10 seconds

# %% [markdown]
# # 8. Conclusion
# The script efficiently scrapes car listings from Carlist.my, extracting both HTML and JSON data, and saves it to a CSV file for further use. This process includes handling missing data, extracting structured information, and respecting website policies by adding a delay between requests.

# %% [markdown]
# # Full Code

# %% [markdown]
# ```python
# import urllib.request
# from bs4 import BeautifulSoup, NavigableString
# import csv
# import time
# import json
#
# # Configuration
# base_url = "https://www.carlist.my/cars-for-sale/malaysia?page_number={}&page_size=25"
# start_page = 6001    # Starting page number to scrape
# end_page = 6977      # Ending page number to scrape
# car_listings = []  # List to store car listings data
#
# output_file = 'D:/camily_carlist_listings_2.csv'
#
# # Get HTML attribute or empty string if attribute doesn't exist
# def get_attr(element, attr_name):
#     return element.get(attr_name, '') if element else ''
#
# # Get the first text node inside a <div> (ignores non-text elements)
# def get_first_text_node(div):
#     for node in div.contents if div else []:
#         if isinstance(node, NavigableString) and node.strip():
#             return node
#     return ''  # Return empty string if no text node is found
#
# # Extract raw mileage information from the article (after the meter icon)
# def get_mileage(article):
#     icon = article.find('i', class_='icon--meter')  # Find meter icon
#     return str(icon.next_sibling) if icon and icon.next_sibling else ''  # Return mileage text
#
# # Extract raw location information from the article (after the location icon)
# def get_location(article):
#     icon = article.find('i', class_='icon--location')  # Find location icon
#     if not icon:
#         return ''
#     text = ''
#     for sib in icon.next_siblings:  # Loop through siblings after icon
#         if isinstance(sib, NavigableString):
#             text += str(sib)
#         elif getattr(sib, 'name', None) == 'span':
#             text += sib.get_text()
#         else:
#             break
#     return text  # Return extracted location text
#
# # Pull JSON-LD block containing the car listings from the page
# def extract_json_ld(soup):
#     for script in soup.find_all('script', type='application/ld+json'):
#         try:
#             data = json.loads(script.string)  # Parse the JSON-LD data
#             if isinstance(data, list):
#                 for d in data:
#                     if 'itemListElement' in d:
#                         return d['itemListElement']  # Return list of car listings
#         except:
#             continue
#     return None  # Return None if no valid JSON-LD is found
#
# # Start time
# start_time = time.time()
#
# # Main scraping loop
# for page_num in range(start_page, end_page + 1):
#     url = base_url.format(page_num)  # Generate URL for the current page
#     print(f"\n🔎 Extracting page {page_num} - {url}")
#
#     # Load the page and parse it with BeautifulSoup
#     req = urllib.request.Request(url, headers={"User-Agent": "Mozilla/5.0"})
#     html = urllib.request.urlopen(req).read()
#     soup = BeautifulSoup(html, 'html.parser')
#
#     # Find all articles (car listings) and extract JSON-LD data
#     articles = soup.find_all('article', class_='listing')
#     ld_json = extract_json_ld(soup)
#     if not ld_json:
#         print("⚠️ No JSON-LD found on this page.")
#         continue
#
#     page_count = 0
#     # Loop through articles and corresponding JSON-LD data
#     for article, item in zip(articles, ld_json):
#         car = item['item']  # Extract JSON details for the car
#
#         # Extract fields from the <article> element’s attributes (HTML-based fields)
#         name = get_attr(article, 'data-title')
#         brand = get_attr(article, 'data-make')
#         model = get_attr(article, 'data-model')
#         body = get_attr(article, 'data-body-type')
#         transmission = get_attr(article, 'data-transmission')
#         installment = get_attr(article, 'data-installment')
#
#         # Extract exactly what is displayed on the page (visible text-based fields)
#         mileage = get_mileage(article)
#         sales_channel = get_first_text_node(article.find('div', class_='listing__spec--dealer'))
#         location = get_location(article)
#
#         # Extract additional fields from the JSON-LD data
#         year = car.get('vehicleModelDate', '')
#         fuel = car.get('fuelType', '')
#         color = car.get('color', '')
#         price = car.get('offers', {}).get('price', '')
#         condition = car.get('itemCondition', '')
#         seats = car.get('seatingCapacity', '')
#
#         # Append the extracted data to the car_listings list
#         car_listings.append({
#             'Car Name': name,
#             'Car Brand': brand,
#             'Car Model': model,
#             'Manufacture Year': year,
#             'Body Type': body,
#             'Fuel Type': fuel,
#             'Mileage': mileage,
#             'Transmission': transmission,
#             'Color': color,
#             'Price': price,
#             'Installment': installment,
#             'Condition': condition,
#             'Seating Capacity': seats,
#             'Location': location,
#             'Sales Channel': sales_channel
#         })
#         page_count += 1
#
#     print(f"✅ Found {page_count} cars on page {page_num}")
#     print(f"📄 Total scraped: {len(car_listings)}")
#     time.sleep(2)  # Sleep to avoid making too many requests in a short time
#
# # Save the extracted data to a CSV file
# if car_listings:
#     with open(output_file, 'w', newline='', encoding='utf-8') as f:
#         writer = csv.DictWriter(f, fieldnames=car_listings[0].keys())
#         writer.writeheader()  # Write the column headers
#         writer.writerows(car_listings)  # Write the car listings data
#     print(f"\n✅ Saved {len(car_listings)} cars to '{output_file}'")
# else:
#     print("\n⚠️ No car listings found.")
#
# # End time and elapsed time calculation
# end_time = time.time()
# execution_time = end_time - start_time
# print(f"\n🕒 Total execution time: {execution_time:.2f} seconds")
# ```
